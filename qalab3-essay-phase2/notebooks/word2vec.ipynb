# %%
from os import path
import re
from zipfile import ZipFile

xml_tag_re = re.compile(r'</?DOC|</?TEXT')


def yield_ja_textbook_zip_lines(zip_file_path, inner_folder_path=None):
    subtree = path.splitext(path.basename(zip_file_path))[0]
    if inner_folder_path:
        subtree = path.join(subtree, inner_folder_path)
    with ZipFile(zip_file_path) as z:
        namelist = z.namelist()
        names = list(filter(lambda x: path.commonpath([subtree, x]) == subtree, namelist))
        for filename in names:
            info = z.getinfo(filename)
            if info.is_dir():
                continue
            with z.open(filename) as f:
                for line in f:
                    line = line.decode('UTF-8').strip()
                    if xml_tag_re.match(line):
                        continue
                    if line.startswith('<Title>'):
                        line = line.replace('<Title>', '').replace('</Title>', '')
                    yield line

# %%
# from joblib import Parallel, delayed
import MeCab


mecab = MeCab.Tagger('-Owakati')


def get_tokenized_line_ja(line):
    return mecab.parse(line).strip()


def yield_tokenized_lines_ja(lines):
    # return Parallel(n_jobs=-3)(delayed(get_tokenized_line_ja)(line) for line in lines)
    for line in lines:
        yield get_tokenized_line_ja(line).split()

# %%
from gensim.models.word2vec import Word2Vec


def get_w2v(lines):
    return Word2Vec(sentences=lines, min_count=1, workers=8)

# %%
tokyoshoseki_generator = yield_ja_textbook_zip_lines(
    'qalab3-essay-phase2/_references/training_set/qalab3-ja-knowledgesource/'
    'qalab3-ja-knowledgesource/make-index-Tokyoshoseki.zip',
    'tokyoshoseki-newxml')
tokenized_tokyoshoseki = yield_tokenized_lines_ja(tokyoshoseki_generator)

# %%
yamakawa_generator = yield_ja_textbook_zip_lines(
    'qalab3-essay-phase2/_references/training_set/qalab3-ja-knowledgesource/'
    'qalab3-ja-knowledgesource/make-index-Yamakawa.zip',
    'yamakawa-Sekaishi-newxml')
tokenized_yamakawa = yield_tokenized_lines_ja(yamakawa_generator)

# %%
# jawiki_generator = yield_ja_textbook_zip_lines(
#     'qalab3-essay-phase2/_references/training_set/jawiki-100M-newxml.zip')
# tokenized_jawiki = yield_tokenized_lines_ja(jawiki_generator)
# Out:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/usr/local/lib/python3.6/site-packages/joblib/pool.py", line 384, in put
#     wlock_acquire()
#   File "/usr/local/lib/python3.6/site-packages/joblib/pool.py", line 384, in put
#     wlock_acquire()
#   File "/usr/local/lib/python3.6/site-packages/joblib/pool.py", line 386, in put
#     return send(obj)
#   File "/usr/local/lib/python3.6/site-packages/joblib/pool.py", line 384, in put
#     wlock_acquire()
#   File "/usr/local/lib/python3.6/site-packages/joblib/pool.py", line 384, in put
#     wlock_acquire()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/lib/python3.6/site-packages/joblib/pool.py", line 372, in send
#     self._writer.send_bytes(buffer.getvalue())
# KeyboardInterrupt
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/connection.py", line 398, in _send_bytes
#     self._send(buf)
#   File "/usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# KeyboardInterrupt

# %%
from itertools import chain


line_list_of_token_list = chain(tokenized_tokyoshoseki, tokenized_yamakawa)

# %%
model_ja = get_w2v(line_list_of_token_list)

# %%
model_ja.wv.vocab
# Out:
# {'さまざま': <gensim.models.keyedvectors.Vocab at 0x10613e358>,
#  'な': <gensim.models.keyedvectors.Vocab at 0x10613e438>,
#  '世界': <gensim.models.keyedvectors.Vocab at 0x10613e320>,
#  'の': <gensim.models.keyedvectors.Vocab at 0x10613e4e0>,
#  '時代': <gensim.models.keyedvectors.Vocab at 0x10613e3c8>,
#  'いろいろ': <gensim.models.keyedvectors.Vocab at 0x10c945828>,
#  '自然': <gensim.models.keyedvectors.Vocab at 0x10c9456a0>,
#  '環境': <gensim.models.keyedvectors.Vocab at 0x10c9456d8>,
#  'もと': <gensim.models.keyedvectors.Vocab at 0x10c945710>,
#  'で': <gensim.models.keyedvectors.Vocab at 0x10c945748>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x10c945860>,
#  '人々': <gensim.models.keyedvectors.Vocab at 0x10c945898>,
#  'は': <gensim.models.keyedvectors.Vocab at 0x10c9458d0>,
#  'その': <gensim.models.keyedvectors.Vocab at 0x10c945908>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x10c945940>,
#  '風土': <gensim.models.keyedvectors.Vocab at 0x10c945978>,
#  'に': <gensim.models.keyedvectors.Vocab at 0x10c9459b0>,
#  '根ざし': <gensim.models.keyedvectors.Vocab at 0x10c9459e8>,
#  'た': <gensim.models.keyedvectors.Vocab at 0x10c945a20>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x10c945a58>,
#  '様式': <gensim.models.keyedvectors.Vocab at 0x10c945a90>,
#  'を': <gensim.models.keyedvectors.Vocab at 0x10c945ac8>,
#  'つくり': <gensim.models.keyedvectors.Vocab at 0x10c945b00>,
#  '独自': <gensim.models.keyedvectors.Vocab at 0x10c945b38>,
#  '「': <gensim.models.keyedvectors.Vocab at 0x10c945b70>,
#  '文化': <gensim.models.keyedvectors.Vocab at 0x10c945ba8>,
#  '」': <gensim.models.keyedvectors.Vocab at 0x10c945be0>,
#  '編みだし': <gensim.models.keyedvectors.Vocab at 0x10c945c18>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x10c945c50>,
#  'すぐれ': <gensim.models.keyedvectors.Vocab at 0x10c945c88>,
#  'いち早く': <gensim.models.keyedvectors.Vocab at 0x10c945cc0>,
#  '考え': <gensim.models.keyedvectors.Vocab at 0x10c945cf8>,
#  'だし': <gensim.models.keyedvectors.Vocab at 0x10c945d30>,
#  'それら': <gensim.models.keyedvectors.Vocab at 0x10c945d68>,
#  '共有': <gensim.models.keyedvectors.Vocab at 0x10c945da0>,
#  'する': <gensim.models.keyedvectors.Vocab at 0x10c945dd8>,
#  'こと': <gensim.models.keyedvectors.Vocab at 0x10c945e10>,
#  '結束': <gensim.models.keyedvectors.Vocab at 0x10c945e48>,
#  'し': <gensim.models.keyedvectors.Vocab at 0x10c945e80>,
#  '一部': <gensim.models.keyedvectors.Vocab at 0x10c945eb8>,
#  '地域': <gensim.models.keyedvectors.Vocab at 0x10c945ef0>,
#  '政治': <gensim.models.keyedvectors.Vocab at 0x10c945f28>,
#  '・': <gensim.models.keyedvectors.Vocab at 0x10c945f60>,
#  '経済': <gensim.models.keyedvectors.Vocab at 0x10c945f98>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x10c945fd0>,
#  '力': <gensim.models.keyedvectors.Vocab at 0x10c954048>,
#  '獲得': <gensim.models.keyedvectors.Vocab at 0x10c954080>,
#  'て': <gensim.models.keyedvectors.Vocab at 0x10c9540b8>,
#  '隣接': <gensim.models.keyedvectors.Vocab at 0x10c9540f0>,
#  '異': <gensim.models.keyedvectors.Vocab at 0x10c954128>,
#  '一帯': <gensim.models.keyedvectors.Vocab at 0x10c954160>,
#  'とりこみ': <gensim.models.keyedvectors.Vocab at 0x10c954198>,
#  'はじめ': <gensim.models.keyedvectors.Vocab at 0x10c9541d0>,
#  'これ': <gensim.models.keyedvectors.Vocab at 0x10c954208>,
#  '応じ': <gensim.models.keyedvectors.Vocab at 0x10c954240>,
#  'も': <gensim.models.keyedvectors.Vocab at 0x10c954278>,
#  'また': <gensim.models.keyedvectors.Vocab at 0x10c9542b0>,
#  '条件': <gensim.models.keyedvectors.Vocab at 0x10c9542e8>,
#  '異なる': <gensim.models.keyedvectors.Vocab at 0x10c954320>,
#  '周辺': <gensim.models.keyedvectors.Vocab at 0x10c954358>,
#  '広がっ': <gensim.models.keyedvectors.Vocab at 0x10c954390>,
#  'ここ': <gensim.models.keyedvectors.Vocab at 0x10c9543c8>,
#  'オリエント': <gensim.models.keyedvectors.Vocab at 0x10c954400>,
#  '地中海': <gensim.models.keyedvectors.Vocab at 0x10c954438>,
#  '南': <gensim.models.keyedvectors.Vocab at 0x10c954470>,
#  'アジア': <gensim.models.keyedvectors.Vocab at 0x10c9544a8>,
#  '東アジア': <gensim.models.keyedvectors.Vocab at 0x10c9544e0>,
#  'といった': <gensim.models.keyedvectors.Vocab at 0x10c954518>,
#  'より': <gensim.models.keyedvectors.Vocab at 0x10c954550>,
#  '広範囲': <gensim.models.keyedvectors.Vocab at 0x10c954588>,
#  'いくつ': <gensim.models.keyedvectors.Vocab at 0x10c9545c0>,
#  'か': <gensim.models.keyedvectors.Vocab at 0x10c9545f8>,
#  '文明': <gensim.models.keyedvectors.Vocab at 0x10c954630>,
#  'が': <gensim.models.keyedvectors.Vocab at 0x10c954668>,
#  '誕生': <gensim.models.keyedvectors.Vocab at 0x10c9546a0>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x10c9546d8>,
#  '以前': <gensim.models.keyedvectors.Vocab at 0x10c954710>,
#  '人類': <gensim.models.keyedvectors.Vocab at 0x10c954748>,
#  '地球': <gensim.models.keyedvectors.Vocab at 0x10c954780>,
#  '登場': <gensim.models.keyedvectors.Vocab at 0x10c9547b8>,
#  'から': <gensim.models.keyedvectors.Vocab at 0x10c9547f0>,
#  'およそ': <gensim.models.keyedvectors.Vocab at 0x10c954828>,
#  '４': <gensim.models.keyedvectors.Vocab at 0x10c954860>,
#  '０': <gensim.models.keyedvectors.Vocab at 0x10c954898>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x10c9548d0>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x10c954908>,
#  '歳月': <gensim.models.keyedvectors.Vocab at 0x10c954940>,
#  '流れ': <gensim.models.keyedvectors.Vocab at 0x10c954978>,
#  'しかし': <gensim.models.keyedvectors.Vocab at 0x10c9549b0>,
#  '長い': <gensim.models.keyedvectors.Vocab at 0x10c9549e8>,
#  '足跡': <gensim.models.keyedvectors.Vocab at 0x10c954a20>,
#  'すべて': <gensim.models.keyedvectors.Vocab at 0x10c954a58>,
#  'たどる': <gensim.models.keyedvectors.Vocab at 0x10c954a90>,
#  'でき': <gensim.models.keyedvectors.Vocab at 0x10c954ac8>,
#  'ない': <gensim.models.keyedvectors.Vocab at 0x10c954b00>,
#  '歴史': <gensim.models.keyedvectors.Vocab at 0x10c954b38>,
#  '圧倒的': <gensim.models.keyedvectors.Vocab at 0x10c954b70>,
#  '部分': <gensim.models.keyedvectors.Vocab at 0x10c954ba8>,
#  '文字': <gensim.models.keyedvectors.Vocab at 0x10c954be0>,
#  'による': <gensim.models.keyedvectors.Vocab at 0x10c954c18>,
#  '記録': <gensim.models.keyedvectors.Vocab at 0x10c954c50>,
#  'もた': <gensim.models.keyedvectors.Vocab at 0x10c954c88>,
#  '属する': <gensim.models.keyedvectors.Vocab at 0x10c954cc0>,
#  'ある': <gensim.models.keyedvectors.Vocab at 0x10c954cf8>,
#  '学': <gensim.models.keyedvectors.Vocab at 0x10c954d30>,
#  'そもそも': <gensim.models.keyedvectors.Vocab at 0x10c954d68>,
#  'たよる': <gensim.models.keyedvectors.Vocab at 0x10c954da0>,
#  '学問': <gensim.models.keyedvectors.Vocab at 0x10c954dd8>,
#  '発明': <gensim.models.keyedvectors.Vocab at 0x10c954e10>,
#  'さ': <gensim.models.keyedvectors.Vocab at 0x10c954e48>,
#  'れ': <gensim.models.keyedvectors.Vocab at 0x10c954e80>,
#  '残さ': <gensim.models.keyedvectors.Vocab at 0x10c954eb8>,
#  'れる': <gensim.models.keyedvectors.Vocab at 0x10c954ef0>,
#  'よう': <gensim.models.keyedvectors.Vocab at 0x10c954f28>,
#  'なる': <gensim.models.keyedvectors.Vocab at 0x10c954f60>,
#  'せいぜい': <gensim.models.keyedvectors.Vocab at 0x10c954f98>,
#  '紀元前': <gensim.models.keyedvectors.Vocab at 0x10c954fd0>,
#  '３': <gensim.models.keyedvectors.Vocab at 0x10ca6e048>,
#  'ごろ': <gensim.models.keyedvectors.Vocab at 0x10ca6e080>,
#  'すぎ': <gensim.models.keyedvectors.Vocab at 0x10ca6e0b8>,
#  'この': <gensim.models.keyedvectors.Vocab at 0x10ca6e0f0>,
#  'ため': <gensim.models.keyedvectors.Vocab at 0x10ca6e128>,
#  '先史': <gensim.models.keyedvectors.Vocab at 0x10ca6e160>,
#  'と': <gensim.models.keyedvectors.Vocab at 0x10ca6e198>,
#  'よば': <gensim.models.keyedvectors.Vocab at 0x10ca6e1d0>,
#  '区別': <gensim.models.keyedvectors.Vocab at 0x10ca6e208>,
#  'わずか': <gensim.models.keyedvectors.Vocab at 0x10ca6e240>,
#  '５': <gensim.models.keyedvectors.Vocab at 0x10ca6e278>,
#  '千': <gensim.models.keyedvectors.Vocab at 0x10ca6e2b0>,
#  'ほど': <gensim.models.keyedvectors.Vocab at 0x10ca6e2e8>,
#  'しか': <gensim.models.keyedvectors.Vocab at 0x10ca6e320>,
#  'なく': <gensim.models.keyedvectors.Vocab at 0x10ca6e358>,
#  '史': <gensim.models.keyedvectors.Vocab at 0x10ca6e390>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x10ca6e3c8>,
#  '埋もれ': <gensim.models.keyedvectors.Vocab at 0x10ca6e400>,
#  'まま': <gensim.models.keyedvectors.Vocab at 0x10ca6e438>,
#  'それ': <gensim.models.keyedvectors.Vocab at 0x10ca6e470>,
#  'かかわら': <gensim.models.keyedvectors.Vocab at 0x10ca6e4a8>,
#  'ず': <gensim.models.keyedvectors.Vocab at 0x10ca6e4e0>,
#  'や': <gensim.models.keyedvectors.Vocab at 0x10ca6e518>,
#  'について': <gensim.models.keyedvectors.Vocab at 0x10ca6e550>,
#  '考古学': <gensim.models.keyedvectors.Vocab at 0x10ca6e588>,
#  '民族': <gensim.models.keyedvectors.Vocab at 0x10ca6e5c0>,
#  'など': <gensim.models.keyedvectors.Vocab at 0x10ca6e5f8>,
#  '研究': <gensim.models.keyedvectors.Vocab at 0x10ca6e630>,
#  '成果': <gensim.models.keyedvectors.Vocab at 0x10ca6e668>,
#  'によって': <gensim.models.keyedvectors.Vocab at 0x10ca6e6a0>,
#  '今日': <gensim.models.keyedvectors.Vocab at 0x10ca6e6d8>,
#  'かなり': <gensim.models.keyedvectors.Vocab at 0x10ca6e710>,
#  'わかっ': <gensim.models.keyedvectors.Vocab at 0x10ca6e748>,
#  'いる': <gensim.models.keyedvectors.Vocab at 0x10ca6e780>,
#  '文書': <gensim.models.keyedvectors.Vocab at 0x10ca6e7b8>,
#  '残る': <gensim.models.keyedvectors.Vocab at 0x10ca6e7f0>,
#  '出来事': <gensim.models.keyedvectors.Vocab at 0x10ca6e828>,
#  '理解': <gensim.models.keyedvectors.Vocab at 0x10ca6e860>,
#  '欠か': <gensim.models.keyedvectors.Vocab at 0x10ca6e898>,
#  'せ': <gensim.models.keyedvectors.Vocab at 0x10ca6e8d0>,
#  'もの': <gensim.models.keyedvectors.Vocab at 0x10ca6e908>,
#  'なっ': <gensim.models.keyedvectors.Vocab at 0x10ca6e940>,
#  '章': <gensim.models.keyedvectors.Vocab at 0x10ca6e978>,
#  '到達': <gensim.models.keyedvectors.Vocab at 0x10ca6e9b0>,
#  'まで': <gensim.models.keyedvectors.Vocab at 0x10ca6e9e8>,
#  '想像': <gensim.models.keyedvectors.Vocab at 0x10ca6ea20>,
#  '絶する': <gensim.models.keyedvectors.Vocab at 0x10ca6ea58>,
#  '長大': <gensim.models.keyedvectors.Vocab at 0x10ca6ea90>,
#  '道程': <gensim.models.keyedvectors.Vocab at 0x10ca6eac8>,
#  'たどり': <gensim.models.keyedvectors.Vocab at 0x10ca6eb00>,
#  'ながら': <gensim.models.keyedvectors.Vocab at 0x10ca6eb38>,
#  '学ぶ': <gensim.models.keyedvectors.Vocab at 0x10ca6eb70>,
#  'しよ': <gensim.models.keyedvectors.Vocab at 0x10ca6eba8>,
#  'う': <gensim.models.keyedvectors.Vocab at 0x10ca6ebe0>,
#  '出現': <gensim.models.keyedvectors.Vocab at 0x10ca6ec18>,
#  '生物': <gensim.models.keyedvectors.Vocab at 0x10ca6ec50>,
#  '分類': <gensim.models.keyedvectors.Vocab at 0x10ca6ec88>,
#  'よれ': <gensim.models.keyedvectors.Vocab at 0x10ca6ecc0>,
#  'ば': <gensim.models.keyedvectors.Vocab at 0x10ca6ecf8>,
#  '哺乳': <gensim.models.keyedvectors.Vocab at 0x10ca6ed30>,
#  '動物': <gensim.models.keyedvectors.Vocab at 0x10ca6ed68>,
#  'なか': <gensim.models.keyedvectors.Vocab at 0x10ca6eda0>,
#  'でも': <gensim.models.keyedvectors.Vocab at 0x10ca6edd8>,
#  '猿': <gensim.models.keyedvectors.Vocab at 0x10ca6ee10>,
#  '同じ': <gensim.models.keyedvectors.Vocab at 0x10ca6ee48>,
#  '霊長': <gensim.models.keyedvectors.Vocab at 0x10ca6ee80>,
#  '類': <gensim.models.keyedvectors.Vocab at 0x10ca6eeb8>,
#  'ほか': <gensim.models.keyedvectors.Vocab at 0x10ca6eef0>,
#  '二': <gensim.models.keyedvectors.Vocab at 0x10ca6ef28>,
#  '本': <gensim.models.keyedvectors.Vocab at 0x10ca6ef60>,
#  '足': <gensim.models.keyedvectors.Vocab at 0x10ca6ef98>,
#  '直立': <gensim.models.keyedvectors.Vocab at 0x10ca6efd0>,
#  '歩行': <gensim.models.keyedvectors.Vocab at 0x10ca6f048>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x10ca6f080>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x10ca6f0b8>,
#  'できる': <gensim.models.keyedvectors.Vocab at 0x10ca6f0f0>,
#  'さらに': <gensim.models.keyedvectors.Vocab at 0x10ca6f128>,
#  '頭部': <gensim.models.keyedvectors.Vocab at 0x10ca6f160>,
#  '背骨': <gensim.models.keyedvectors.Vocab at 0x10ca6f198>,
#  'バランス': <gensim.models.keyedvectors.Vocab at 0x10ca6f1d0>,
#  'よく': <gensim.models.keyedvectors.Vocab at 0x10ca6f208>,
#  '保て': <gensim.models.keyedvectors.Vocab at 0x10ca6f240>,
#  '両手': <gensim.models.keyedvectors.Vocab at 0x10ca6f278>,
#  '自由': <gensim.models.keyedvectors.Vocab at 0x10ca6f2b0>,
#  '操る': <gensim.models.keyedvectors.Vocab at 0x10ca6f2e8>,
#  '機能': <gensim.models.keyedvectors.Vocab at 0x10ca6f320>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x10ca6f358>,
#  'につれて': <gensim.models.keyedvectors.Vocab at 0x10ca6f390>,
#  '大きな': <gensim.models.keyedvectors.Vocab at 0x10ca6f3c8>,
#  '容量': <gensim.models.keyedvectors.Vocab at 0x10ca6f400>,
#  '頭脳': <gensim.models.keyedvectors.Vocab at 0x10ca6f438>,
#  '発達': <gensim.models.keyedvectors.Vocab at 0x10ca6f470>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x10ca6f4a8>,
#  '世代': <gensim.models.keyedvectors.Vocab at 0x10ca6f4e0>,
#  '生みだし': <gensim.models.keyedvectors.Vocab at 0x10ca6f518>,
#  '知識': <gensim.models.keyedvectors.Vocab at 0x10ca6f550>,
#  '技術': <gensim.models.keyedvectors.Vocab at 0x10ca6f588>,
#  '受け': <gensim.models.keyedvectors.Vocab at 0x10ca6f5c0>,
#  'つぎ': <gensim.models.keyedvectors.Vocab at 0x10ca6f5f8>,
#  'せる': <gensim.models.keyedvectors.Vocab at 0x10ca6f630>,
#  '進化': <gensim.models.keyedvectors.Vocab at 0x10ca6f668>,
#  '過程': <gensim.models.keyedvectors.Vocab at 0x10ca6f6a0>,
#  'たどっ': <gensim.models.keyedvectors.Vocab at 0x10ca6f6d8>,
#  '現在': <gensim.models.keyedvectors.Vocab at 0x10ca6f710>,
#  'いたっ': <gensim.models.keyedvectors.Vocab at 0x10ca6f748>,
#  '明らか': <gensim.models.keyedvectors.Vocab at 0x10ca6f780>,
#  '多く': <gensim.models.keyedvectors.Vocab at 0x10ca6f7b8>,
#  '古': <gensim.models.keyedvectors.Vocab at 0x10ca6f7f0>,
#  '生': <gensim.models.keyedvectors.Vocab at 0x10ca6f828>,
#  '化石': <gensim.models.keyedvectors.Vocab at 0x10ca6f860>,
#  '骨': <gensim.models.keyedvectors.Vocab at 0x10ca6f898>,
#  '遺跡': <gensim.models.keyedvectors.Vocab at 0x10ca6f8d0>,
#  '遺物': <gensim.models.keyedvectors.Vocab at 0x10ca6f908>,
#  '発見': <gensim.models.keyedvectors.Vocab at 0x10ca6f940>,
#  'よる': <gensim.models.keyedvectors.Vocab at 0x10ca6f978>,
#  'とともに': <gensim.models.keyedvectors.Vocab at 0x10ca6f9b0>,
#  '発展': <gensim.models.keyedvectors.Vocab at 0x10ca6f9e8>,
#  'はっきり': <gensim.models.keyedvectors.Vocab at 0x10ca6fa20>,
#  '識別': <gensim.models.keyedvectors.Vocab at 0x10ca6fa58>,
#  '最古': <gensim.models.keyedvectors.Vocab at 0x10ca6fa90>,
#  'アフリカ': <gensim.models.keyedvectors.Vocab at 0x10ca6fac8>,
#  '一群': <gensim.models.keyedvectors.Vocab at 0x10ca6fb00>,
#  'アウストラロピテクス': <gensim.models.keyedvectors.Vocab at 0x10ca6fb38>,
#  'おそらく': <gensim.models.keyedvectors.Vocab at 0x10ca6fb70>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x10ca6fba8>,
#  'さかのぼる': <gensim.models.keyedvectors.Vocab at 0x10ca6fbe0>,
#  'やがて': <gensim.models.keyedvectors.Vocab at 0x10ca6fc18>,
#  '２': <gensim.models.keyedvectors.Vocab at 0x10ca6fc50>,
#  '彼ら': <gensim.models.keyedvectors.Vocab at 0x10ca6fc88>,
#  '石': <gensim.models.keyedvectors.Vocab at 0x10ca6fcc0>,
#  '打ち': <gensim.models.keyedvectors.Vocab at 0x10ca6fcf8>,
#  'かい': <gensim.models.keyedvectors.Vocab at 0x10ca6fd30>,
#  'つくっ': <gensim.models.keyedvectors.Vocab at 0x10ca6fd68>,
#  '打': <gensim.models.keyedvectors.Vocab at 0x10ca6fda0>,
#  '製': <gensim.models.keyedvectors.Vocab at 0x10ca6fdd8>,
#  '石器': <gensim.models.keyedvectors.Vocab at 0x10ca6fe10>,
#  '礫': <gensim.models.keyedvectors.Vocab at 0x10ca6fe48>,
#  '道具': <gensim.models.keyedvectors.Vocab at 0x10ca6fe80>,
#  'として': <gensim.models.keyedvectors.Vocab at 0x10ca6feb8>,
#  '使い': <gensim.models.keyedvectors.Vocab at 0x10ca6fef0>,
#  'サヴァナ': <gensim.models.keyedvectors.Vocab at 0x10ca6ff28>,
#  '地帯': <gensim.models.keyedvectors.Vocab at 0x10ca6ff60>,
#  '豊富': <gensim.models.keyedvectors.Vocab at 0x10ca6ff98>,
#  '動植物': <gensim.models.keyedvectors.Vocab at 0x10ca6ffd0>,
#  '狩猟': <gensim.models.keyedvectors.Vocab at 0x10ca75048>,
#  '採集': <gensim.models.keyedvectors.Vocab at 0x10ca75080>,
#  'い': <gensim.models.keyedvectors.Vocab at 0x10ca750b8>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x10ca750f0>,
#  'とくに': <gensim.models.keyedvectors.Vocab at 0x10ca75128>,
#  '脳': <gensim.models.keyedvectors.Vocab at 0x10ca75160>,
#  '大きく': <gensim.models.keyedvectors.Vocab at 0x10ca75198>,
#  'ホモ': <gensim.models.keyedvectors.Vocab at 0x10ca751d0>,
#  '＝': <gensim.models.keyedvectors.Vocab at 0x10ca75208>,
#  'ハビリス': <gensim.models.keyedvectors.Vocab at 0x10ca75240>,
#  '～': <gensim.models.keyedvectors.Vocab at 0x10ca75278>,
#  '１': <gensim.models.keyedvectors.Vocab at 0x10ca752b0>,
#  '７': <gensim.models.keyedvectors.Vocab at 0x10ca752e8>,
#  'ころ': <gensim.models.keyedvectors.Vocab at 0x10ca75320>,
#  '考古': <gensim.models.keyedvectors.Vocab at 0x10ca75358>,
#  '旧石器時代': <gensim.models.keyedvectors.Vocab at 0x10ca75390>,
#  'はじまる': <gensim.models.keyedvectors.Vocab at 0x10ca753c8>,
#  '原人': <gensim.models.keyedvectors.Vocab at 0x10ca75400>,
#  '新人': <gensim.models.keyedvectors.Vocab at 0x10ca75438>,
#  'へ': <gensim.models.keyedvectors.Vocab at 0x10ca75470>,
#  '８': <gensim.models.keyedvectors.Vocab at 0x10ca754a8>,
#  'エレクトゥス': <gensim.models.keyedvectors.Vocab at 0x10ca754e0>,
#  '出': <gensim.models.keyedvectors.Vocab at 0x10ca75518>,
#  '各地': <gensim.models.keyedvectors.Vocab at 0x10ca75550>,
#  '分散': <gensim.models.keyedvectors.Vocab at 0x10ca75588>,
#  '東南アジア': <gensim.models.keyedvectors.Vocab at 0x10ca755c0>,
#  'られる': <gensim.models.keyedvectors.Vocab at 0x10ca755f8>,
#  '好例': <gensim.models.keyedvectors.Vocab at 0x10ca75630>,
#  'ジャワ島': <gensim.models.keyedvectors.Vocab at 0x10ca75668>,
#  'ジャワ': <gensim.models.keyedvectors.Vocab at 0x10ca756a0>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x10ca756d8>,
#  '周': <gensim.models.keyedvectors.Vocab at 0x10ca75710>,
#  '口': <gensim.models.keyedvectors.Vocab at 0x10ca75748>,
#  '店': <gensim.models.keyedvectors.Vocab at 0x10ca75780>,
#  '出土': <gensim.models.keyedvectors.Vocab at 0x10ca757b8>,
#  '６': <gensim.models.keyedvectors.Vocab at 0x10ca757f0>,
#  '北京': <gensim.models.keyedvectors.Vocab at 0x10ca75828>,
#  '近年': <gensim.models.keyedvectors.Vocab at 0x10ca75860>,
#  '古い': <gensim.models.keyedvectors.Vocab at 0x10ca75898>,
#  'いわ': <gensim.models.keyedvectors.Vocab at 0x10ca758d0>,
#  '洞窟': <gensim.models.keyedvectors.Vocab at 0x10ca75908>,
#  '住み': <gensim.models.keyedvectors.Vocab at 0x10ca75940>,
#  '火': <gensim.models.keyedvectors.Vocab at 0x10ca75978>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x10ca759b0>,
#  '知っ': <gensim.models.keyedvectors.Vocab at 0x10ca759e8>,
#  'おり': <gensim.models.keyedvectors.Vocab at 0x10ca75a20>,
#  '会話': <gensim.models.keyedvectors.Vocab at 0x10ca75a58>,
#  '言語': <gensim.models.keyedvectors.Vocab at 0x10ca75a90>,
#  '能力': <gensim.models.keyedvectors.Vocab at 0x10ca75ac8>,
#  'もっ': <gensim.models.keyedvectors.Vocab at 0x10ca75b00>,
#  '旧人': <gensim.models.keyedvectors.Vocab at 0x10ca75b38>,
#  'あらわれ': <gensim.models.keyedvectors.Vocab at 0x10ca75b70>,
#  '現': <gensim.models.keyedvectors.Vocab at 0x10ca75ba8>,
#  'ほぼ': <gensim.models.keyedvectors.Vocab at 0x10ca75be0>,
#  '容積': <gensim.models.keyedvectors.Vocab at 0x10ca75c18>,
#  '大脳': <gensim.models.keyedvectors.Vocab at 0x10ca75c50>,
#  'もつ': <gensim.models.keyedvectors.Vocab at 0x10ca75c88>,
#  '用途': <gensim.models.keyedvectors.Vocab at 0x10ca75cc0>,
#  '種類': <gensim.models.keyedvectors.Vocab at 0x10ca75cf8>,
#  '毛皮': <gensim.models.keyedvectors.Vocab at 0x10ca75d30>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x10ca75d68>,
#  'まとっ': <gensim.models.keyedvectors.Vocab at 0x10ca75da0>,
#  '死者': <gensim.models.keyedvectors.Vocab at 0x10ca75dd8>,
#  '埋葬': <gensim.models.keyedvectors.Vocab at 0x10ca75e10>,
#  '身体': <gensim.models.keyedvectors.Vocab at 0x10ca75e48>,
#  '彩色': <gensim.models.keyedvectors.Vocab at 0x10ca75e80>,
#  '例': <gensim.models.keyedvectors.Vocab at 0x10ca75eb8>,
#  'あり': <gensim.models.keyedvectors.Vocab at 0x10ca75ef0>,
#  '宗教': <gensim.models.keyedvectors.Vocab at 0x10ca75f28>,
#  '意識': <gensim.models.keyedvectors.Vocab at 0x10ca75f60>,
#  '美意識': <gensim.models.keyedvectors.Vocab at 0x10ca75f98>,
#  'めばえ': <gensim.models.keyedvectors.Vocab at 0x10ca75fd0>,
#  'らしい': <gensim.models.keyedvectors.Vocab at 0x10ca78048>,
#  '同質': <gensim.models.keyedvectors.Vocab at 0x10ca78080>,
#  'られ': <gensim.models.keyedvectors.Vocab at 0x10ca780b8>,
#  'ヨーロッパ': <gensim.models.keyedvectors.Vocab at 0x10ca780f0>,
#  '居住': <gensim.models.keyedvectors.Vocab at 0x10ca78128>,
#  'ネアンデルタール': <gensim.models.keyedvectors.Vocab at 0x10ca78160>,
#  'サピエンス': <gensim.models.keyedvectors.Vocab at 0x10ca78198>,
#  'ネアンデルターレンシス': <gensim.models.keyedvectors.Vocab at 0x10ca781d0>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x10ca78208>,
#  '少なくとも': <gensim.models.keyedvectors.Vocab at 0x10ca78240>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x10ca78278>,
#  'つながる': <gensim.models.keyedvectors.Vocab at 0x10ca782b0>,
#  '最初': <gensim.models.keyedvectors.Vocab at 0x10ca782e8>,
#  'フランス': <gensim.models.keyedvectors.Vocab at 0x10ca78320>,
#  'クロマニョン': <gensim.models.keyedvectors.Vocab at 0x10ca78358>,
#  'その後': <gensim.models.keyedvectors.Vocab at 0x10ca78390>,
#  'イタリア': <gensim.models.keyedvectors.Vocab at 0x10ca783c8>,
#  'グリマルディ': <gensim.models.keyedvectors.Vocab at 0x10ca78400>,
#  '上洞': <gensim.models.keyedvectors.Vocab at 0x10ca78438>,
#  '静岡': <gensim.models.keyedvectors.Vocab at 0x10ca78470>,
#  '県': <gensim.models.keyedvectors.Vocab at 0x10ca784a8>,
#  '浜北': <gensim.models.keyedvectors.Vocab at 0x10ca784e0>,
#  'なお': <gensim.models.keyedvectors.Vocab at 0x10ca78518>,
#  '起源': <gensim.models.keyedvectors.Vocab at 0x10ca78550>,
#  '説': <gensim.models.keyedvectors.Vocab at 0x10ca78588>,
#  '有力': <gensim.models.keyedvectors.Vocab at 0x10ca785c0>,
#  '石塊': <gensim.models.keyedvectors.Vocab at 0x10ca785f8>,
#  'かけ': <gensim.models.keyedvectors.Vocab at 0x10ca78630>,
#  'ら': <gensim.models.keyedvectors.Vocab at 0x10ca78668>,
#  'そぎ': <gensim.models.keyedvectors.Vocab at 0x10ca786a0>,
#  'おとし': <gensim.models.keyedvectors.Vocab at 0x10ca786d8>,
#  '片': <gensim.models.keyedvectors.Vocab at 0x10ca78710>,
#  '矢じり': <gensim.models.keyedvectors.Vocab at 0x10ca78748>,
#  '槍': <gensim.models.keyedvectors.Vocab at 0x10ca78780>,
#  '穂先': <gensim.models.keyedvectors.Vocab at 0x10ca787b8>,
#  'つくる': <gensim.models.keyedvectors.Vocab at 0x10ca787f0>,
#  '身': <gensim.models.keyedvectors.Vocab at 0x10ca78828>,
#  'つけ': <gensim.models.keyedvectors.Vocab at 0x10ca78860>,
#  'ハク': <gensim.models.keyedvectors.Vocab at 0x10ca78898>,
#  '角': <gensim.models.keyedvectors.Vocab at 0x10ca788d0>,
#  '材料': <gensim.models.keyedvectors.Vocab at 0x10ca78908>,
#  '器': <gensim.models.keyedvectors.Vocab at 0x10ca78940>,
#  '釣針': <gensim.models.keyedvectors.Vocab at 0x10ca78978>,
#  '縫針': <gensim.models.keyedvectors.Vocab at 0x10ca789b0>,
#  '銛': <gensim.models.keyedvectors.Vocab at 0x10ca789e8>,
#  '利用': <gensim.models.keyedvectors.Vocab at 0x10ca78a20>,
#  'こうして': <gensim.models.keyedvectors.Vocab at 0x10ca78a58>,
#  '漁撈': <gensim.models.keyedvectors.Vocab at 0x10ca78a90>,
#  '高まり': <gensim.models.keyedvectors.Vocab at 0x10ca78ac8>,
#  'うるおい': <gensim.models.keyedvectors.Vocab at 0x10ca78b00>,
#  '生まれ': <gensim.models.keyedvectors.Vocab at 0x10ca78b38>,
#  '多産': <gensim.models.keyedvectors.Vocab at 0x10ca78b70>,
#  '豊穣': <gensim.models.keyedvectors.Vocab at 0x10ca78ba8>,
#  '祈る': <gensim.models.keyedvectors.Vocab at 0x10ca78be0>,
#  '呪術': <gensim.models.keyedvectors.Vocab at 0x10ca78c18>,
#  '儀礼': <gensim.models.keyedvectors.Vocab at 0x10ca78c50>,
#  '広まり': <gensim.models.keyedvectors.Vocab at 0x10ca78c88>,
#  '豊満': <gensim.models.keyedvectors.Vocab at 0x10ca78cc0>,
#  '女性': <gensim.models.keyedvectors.Vocab at 0x10ca78cf8>,
#  '裸像': <gensim.models.keyedvectors.Vocab at 0x10ca78d30>,
#  '北': <gensim.models.keyedvectors.Vocab at 0x10ca78d68>,
#  'スペイン': <gensim.models.keyedvectors.Vocab at 0x10ca78da0>,
#  'アルタミラ': <gensim.models.keyedvectors.Vocab at 0x10ca78dd8>,
#  'ラスコー': <gensim.models.keyedvectors.Vocab at 0x10ca78e10>,
#  '絵画': <gensim.models.keyedvectors.Vocab at 0x10ca78e48>,
#  'そこ': <gensim.models.keyedvectors.Vocab at 0x10ca78e80>,
#  '写実': <gensim.models.keyedvectors.Vocab at 0x10ca78eb8>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x10ca78ef0>,
#  '描か': <gensim.models.keyedvectors.Vocab at 0x10ca78f28>,
#  '観察': <gensim.models.keyedvectors.Vocab at 0x10ca78f60>,
#  '表現': <gensim.models.keyedvectors.Vocab at 0x10ca78f98>,
#  'において': <gensim.models.keyedvectors.Vocab at 0x10ca78fd0>,
#  '大いなる': <gensim.models.keyedvectors.Vocab at 0x10ca7b048>,
#  '進歩': <gensim.models.keyedvectors.Vocab at 0x10ca7b080>,
#  '示し': <gensim.models.keyedvectors.Vocab at 0x10ca7b0b8>,
#  '後期': <gensim.models.keyedvectors.Vocab at 0x10ca7b0f0>,
#  'とよん': <gensim.models.keyedvectors.Vocab at 0x10ca7b128>,
#  '間': <gensim.models.keyedvectors.Vocab at 0x10ca7b160>,
#  'という': <gensim.models.keyedvectors.Vocab at 0x10ca7b198>,
#  'ユーラシア': <gensim.models.keyedvectors.Vocab at 0x10ca7b1d0>,
#  'ほとんど': <gensim.models.keyedvectors.Vocab at 0x10ca7b208>,
#  '住む': <gensim.models.keyedvectors.Vocab at 0x10ca7b240>,
#  '陸': <gensim.models.keyedvectors.Vocab at 0x10ca7b278>,
#  'つづき': <gensim.models.keyedvectors.Vocab at 0x10ca7b2b0>,
#  'あっ': <gensim.models.keyedvectors.Vocab at 0x10ca7b2e8>,
#  'ベーリング海': <gensim.models.keyedvectors.Vocab at 0x10ca7b320>,
#  '峡': <gensim.models.keyedvectors.Vocab at 0x10ca7b358>,
#  '通っ': <gensim.models.keyedvectors.Vocab at 0x10ca7b390>,
#  'アメリカ大陸': <gensim.models.keyedvectors.Vocab at 0x10ca7b3c8>,
#  '移住': <gensim.models.keyedvectors.Vocab at 0x10ca7b400>,
#  'アメリカ': <gensim.models.keyedvectors.Vocab at 0x10ca7b438>,
#  '南端': <gensim.models.keyedvectors.Vocab at 0x10ca7b470>,
#  'フエゴ': <gensim.models.keyedvectors.Vocab at 0x10ca7b4a8>,
#  '島': <gensim.models.keyedvectors.Vocab at 0x10ca7b4e0>,
#  'オセアニア': <gensim.models.keyedvectors.Vocab at 0x10ca7b518>,
#  '進出': <gensim.models.keyedvectors.Vocab at 0x10ca7b550>,
#  '者': <gensim.models.keyedvectors.Vocab at 0x10ca7b588>,
#  '広まる': <gensim.models.keyedvectors.Vocab at 0x10ca7b5c0>,
#  'ごと': <gensim.models.keyedvectors.Vocab at 0x10ca7b5f8>,
#  '差異': <gensim.models.keyedvectors.Vocab at 0x10ca7b630>,
#  '生じ': <gensim.models.keyedvectors.Vocab at 0x10ca7b668>,
#  'モンゴロイド': <gensim.models.keyedvectors.Vocab at 0x10ca7b6a0>,
#  'コーカソイド': <gensim.models.keyedvectors.Vocab at 0x10ca7b6d8>,
#  'ネグロイド': <gensim.models.keyedvectors.Vocab at 0x10ca7b710>,
#  '形質': <gensim.models.keyedvectors.Vocab at 0x10ca7b748>,
#  'ちがい': <gensim.models.keyedvectors.Vocab at 0x10ca7b780>,
#  '拡散': <gensim.models.keyedvectors.Vocab at 0x10ca7b7b8>,
#  'ともなっ': <gensim.models.keyedvectors.Vocab at 0x10ca7b7f0>,
#  '形成': <gensim.models.keyedvectors.Vocab at 0x10ca7b828>,
#  'いっ': <gensim.models.keyedvectors.Vocab at 0x10ca7b860>,
#  '故': <gensim.models.keyedvectors.Vocab at 0x10ca7b898>,
#  '同じく': <gensim.models.keyedvectors.Vocab at 0x10ca7b8d0>,
#  '語法': <gensim.models.keyedvectors.Vocab at 0x10ca7b908>,
#  '類似': <gensim.models.keyedvectors.Vocab at 0x10ca7b940>,
#  '語族': <gensim.models.keyedvectors.Vocab at 0x10ca7b978>,
#  '用語': <gensim.models.keyedvectors.Vocab at 0x10ca7b9b0>,
#  'くくら': <gensim.models.keyedvectors.Vocab at 0x10ca7b9e8>,
#  '場合': <gensim.models.keyedvectors.Vocab at 0x10ca7ba20>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x10ca7ba58>,
#  '最後': <gensim.models.keyedvectors.Vocab at 0x10ca7ba90>,
#  '氷河期': <gensim.models.keyedvectors.Vocab at 0x10ca7bac8>,
#  '終わり': <gensim.models.keyedvectors.Vocab at 0x10ca7bb00>,
#  '温暖': <gensim.models.keyedvectors.Vocab at 0x10ca7bb38>,
#  '化': <gensim.models.keyedvectors.Vocab at 0x10ca7bb70>,
#  'かわら': <gensim.models.keyedvectors.Vocab at 0x10ca7bba8>,
#  '気候': <gensim.models.keyedvectors.Vocab at 0x10ca7bbe0>,
#  '地形': <gensim.models.keyedvectors.Vocab at 0x10ca7bc18>,
#  '石斧': <gensim.models.keyedvectors.Vocab at 0x10ca7bc50>,
#  '森林': <gensim.models.keyedvectors.Vocab at 0x10ca7bc88>,
#  '伐採': <gensim.models.keyedvectors.Vocab at 0x10ca7bcc0>,
#  'たやすく': <gensim.models.keyedvectors.Vocab at 0x10ca7bcf8>,
#  '山地': <gensim.models.keyedvectors.Vocab at 0x10ca7bd30>,
#  '離れ': <gensim.models.keyedvectors.Vocab at 0x10ca7bd68>,
#  '平地': <gensim.models.keyedvectors.Vocab at 0x10ca7bda0>,
#  '小屋': <gensim.models.keyedvectors.Vocab at 0x10ca7bdd8>,
#  '建て': <gensim.models.keyedvectors.Vocab at 0x10ca7be10>,
#  '砂': <gensim.models.keyedvectors.Vocab at 0x10ca7be48>,
#  '磨い': <gensim.models.keyedvectors.Vocab at 0x10ca7be80>,
#  '刃': <gensim.models.keyedvectors.Vocab at 0x10ca7beb8>,
#  '磨': <gensim.models.keyedvectors.Vocab at 0x10ca7bef0>,
#  'つくりださ': <gensim.models.keyedvectors.Vocab at 0x10ca7bf28>,
#  '作業': <gensim.models.keyedvectors.Vocab at 0x10ca7bf60>,
#  '効率': <gensim.models.keyedvectors.Vocab at 0x10ca7bf98>,
#  '高まっ': <gensim.models.keyedvectors.Vocab at 0x10ca7bfd0>,
#  '鎌': <gensim.models.keyedvectors.Vocab at 0x10cadd048>,
#  '石臼': <gensim.models.keyedvectors.Vocab at 0x10cadd080>,
#  '杵': <gensim.models.keyedvectors.Vocab at 0x10cadd0b8>,
#  '使わ': <gensim.models.keyedvectors.Vocab at 0x10cadd0f0>,
#  '土器': <gensim.models.keyedvectors.Vocab at 0x10cadd128>,
#  'つくら': <gensim.models.keyedvectors.Vocab at 0x10cadd160>,
#  '穀物': <gensim.models.keyedvectors.Vocab at 0x10cadd198>,
#  '調理': <gensim.models.keyedvectors.Vocab at 0x10cadd1d0>,
#  '法': <gensim.models.keyedvectors.Vocab at 0x10cadd208>,
#  '改善': <gensim.models.keyedvectors.Vocab at 0x10cadd240>,
#  'もとづく': <gensim.models.keyedvectors.Vocab at 0x10cadd278>,
#  '期間': <gensim.models.keyedvectors.Vocab at 0x10cadd2b0>,
#  '農耕': <gensim.models.keyedvectors.Vocab at 0x10cadd2e8>,
#  '牧畜': <gensim.models.keyedvectors.Vocab at 0x10cadd320>,
#  'はじまり': <gensim.models.keyedvectors.Vocab at 0x10cadd358>,
#  '家畜': <gensim.models.keyedvectors.Vocab at 0x10cadd390>,
#  '飼育': <gensim.models.keyedvectors.Vocab at 0x10cadd3c8>,
#  '転換': <gensim.models.keyedvectors.Vocab at 0x10cadd400>,
#  'おこっ': <gensim.models.keyedvectors.Vocab at 0x10cadd438>,
#  '食糧': <gensim.models.keyedvectors.Vocab at 0x10cadd470>,
#  '段階': <gensim.models.keyedvectors.Vocab at 0x10cadd4a8>,
#  '生産': <gensim.models.keyedvectors.Vocab at 0x10cadd4e0>,
#  '飛躍': <gensim.models.keyedvectors.Vocab at 0x10cadd518>,
#  '革命': <gensim.models.keyedvectors.Vocab at 0x10cadd550>,
#  'よぶ': <gensim.models.keyedvectors.Vocab at 0x10cadd588>,
#  '大陸': <gensim.models.keyedvectors.Vocab at 0x10cadd5c0>,
#  '北部': <gensim.models.keyedvectors.Vocab at 0x10cadd5f8>,
#  '西南': <gensim.models.keyedvectors.Vocab at 0x10cadd630>,
#  '中央': <gensim.models.keyedvectors.Vocab at 0x10cadd668>,
#  'にかけて': <gensim.models.keyedvectors.Vocab at 0x10cadd6a0>,
#  '巨大': <gensim.models.keyedvectors.Vocab at 0x10cadd6d8>,
#  '砂漠': <gensim.models.keyedvectors.Vocab at 0x10cadd710>,
#  '極度': <gensim.models.keyedvectors.Vocab at 0x10cadd748>,
#  '乾燥': <gensim.models.keyedvectors.Vocab at 0x10cadd780>,
#  '食物': <gensim.models.keyedvectors.Vocab at 0x10cadd7b8>,
#  '育た': <gensim.models.keyedvectors.Vocab at 0x10cadd7f0>,
#  '生業': <gensim.models.keyedvectors.Vocab at 0x10cadd828>,
#  '行う': <gensim.models.keyedvectors.Vocab at 0x10cadd860>,
#  'なかっ': <gensim.models.keyedvectors.Vocab at 0x10cadd898>,
#  'たどりつい': <gensim.models.keyedvectors.Vocab at 0x10cadd8d0>,
#  '営む': <gensim.models.keyedvectors.Vocab at 0x10cadd908>,
#  '周囲': <gensim.models.keyedvectors.Vocab at 0x10cadd940>,
#  '弱い': <gensim.models.keyedvectors.Vocab at 0x10cadd978>,
#  '冬': <gensim.models.keyedvectors.Vocab at 0x10cadd9b0>,
#  '雨': <gensim.models.keyedvectors.Vocab at 0x10cadd9e8>,
#  'だけ': <gensim.models.keyedvectors.Vocab at 0x10cadda20>,
#  '短い': <gensim.models.keyedvectors.Vocab at 0x10cadda58>,
#  '草': <gensim.models.keyedvectors.Vocab at 0x10cadda90>,
#  '生える': <gensim.models.keyedvectors.Vocab at 0x10caddac8>,
#  '広大': <gensim.models.keyedvectors.Vocab at 0x10caddb00>,
#  '草原': <gensim.models.keyedvectors.Vocab at 0x10caddb38>,
#  'ステップ': <gensim.models.keyedvectors.Vocab at 0x10caddb70>,
#  '生長': <gensim.models.keyedvectors.Vocab at 0x10caddba8>,
#  '春': <gensim.models.keyedvectors.Vocab at 0x10caddbe0>,
#  '実': <gensim.models.keyedvectors.Vocab at 0x10caddc18>,
#  '夏': <gensim.models.keyedvectors.Vocab at 0x10caddc50>,
#  '枯れる': <gensim.models.keyedvectors.Vocab at 0x10caddc88>,
#  '冬型': <gensim.models.keyedvectors.Vocab at 0x10caddcc0>,
#  '植物': <gensim.models.keyedvectors.Vocab at 0x10caddcf8>,
#  '生育': <gensim.models.keyedvectors.Vocab at 0x10caddd30>,
#  'これら': <gensim.models.keyedvectors.Vocab at 0x10caddd68>,
#  '野草': <gensim.models.keyedvectors.Vocab at 0x10caddda0>,
#  '異常': <gensim.models.keyedvectors.Vocab at 0x10cadddd8>,
#  'つける': <gensim.models.keyedvectors.Vocab at 0x10cadde10>,
#  '麦': <gensim.models.keyedvectors.Vocab at 0x10cadde48>,
#  '夏季': <gensim.models.keyedvectors.Vocab at 0x10cadde80>,
#  'ので': <gensim.models.keyedvectors.Vocab at 0x10caddeb8>,
#  '対抗': <gensim.models.keyedvectors.Vocab at 0x10caddef0>,
#  '雑草': <gensim.models.keyedvectors.Vocab at 0x10caddf28>,
#  '少なく': <gensim.models.keyedvectors.Vocab at 0x10caddf60>,
#  '栽培': <gensim.models.keyedvectors.Vocab at 0x10caddf98>,
#  '困難': <gensim.models.keyedvectors.Vocab at 0x10caddfd0>,
#  'とりわけ': <gensim.models.keyedvectors.Vocab at 0x10cadf048>,
#  '順調': <gensim.models.keyedvectors.Vocab at 0x10cadf080>,
#  '育つ': <gensim.models.keyedvectors.Vocab at 0x10cadf0b8>,
#  'イラク': <gensim.models.keyedvectors.Vocab at 0x10cadf0f0>,
#  'シリア': <gensim.models.keyedvectors.Vocab at 0x10cadf128>,
#  '農業': <gensim.models.keyedvectors.Vocab at 0x10cadf160>,
#  '築く': <gensim.models.keyedvectors.Vocab at 0x10cadf198>,
#  '開始': <gensim.models.keyedvectors.Vocab at 0x10cadf1d0>,
#  'さかん': <gensim.models.keyedvectors.Vocab at 0x10cadf208>,
#  '貯蔵': <gensim.models.keyedvectors.Vocab at 0x10cadf240>,
#  '用い': <gensim.models.keyedvectors.Vocab at 0x10cadf278>,
#  '赤': <gensim.models.keyedvectors.Vocab at 0x10cadf2b0>,
#  '黒': <gensim.models.keyedvectors.Vocab at 0x10cadf2e8>,
#  '白': <gensim.models.keyedvectors.Vocab at 0x10cadf320>,
#  '顔料': <gensim.models.keyedvectors.Vocab at 0x10cadf358>,
#  '文様': <gensim.models.keyedvectors.Vocab at 0x10cadf390>,
#  '描い': <gensim.models.keyedvectors.Vocab at 0x10cadf3c8>,
#  '彩': <gensim.models.keyedvectors.Vocab at 0x10cadf400>,
#  '文': <gensim.models.keyedvectors.Vocab at 0x10cadf438>,
#  '普及': <gensim.models.keyedvectors.Vocab at 0x10cadf470>,
#  '場所': <gensim.models.keyedvectors.Vocab at 0x10cadf4a8>,
#  '異なっ': <gensim.models.keyedvectors.Vocab at 0x10cadf4e0>,
#  'ちがっ': <gensim.models.keyedvectors.Vocab at 0x10cadf518>,
#  '西': <gensim.models.keyedvectors.Vocab at 0x10cadf550>,
#  '９': <gensim.models.keyedvectors.Vocab at 0x10cadf588>,
#  '羊': <gensim.models.keyedvectors.Vocab at 0x10cadf5c0>,
#  '早く': <gensim.models.keyedvectors.Vocab at 0x10cadf5f8>,
#  'おくれ': <gensim.models.keyedvectors.Vocab at 0x10cadf630>,
#  '牛': <gensim.models.keyedvectors.Vocab at 0x10cadf668>,
#  '豚': <gensim.models.keyedvectors.Vocab at 0x10cadf6a0>,
#  'はじまっ': <gensim.models.keyedvectors.Vocab at 0x10cadf6d8>,
#  'スカンディナヴィア': <gensim.models.keyedvectors.Vocab at 0x10cadf710>,
#  '半島': <gensim.models.keyedvectors.Vocab at 0x10cadf748>,
#  'シベリア': <gensim.models.keyedvectors.Vocab at 0x10cadf780>,
#  '森林地帯': <gensim.models.keyedvectors.Vocab at 0x10cadf7b8>,
#  '知ら': <gensim.models.keyedvectors.Vocab at 0x10cadf7f0>,
#  'アワ': <gensim.models.keyedvectors.Vocab at 0x10cadf828>,
#  '稲': <gensim.models.keyedvectors.Vocab at 0x10cadf860>,
#  '食用': <gensim.models.keyedvectors.Vocab at 0x10cadf898>,
#  '犬': <gensim.models.keyedvectors.Vocab at 0x10cadf8d0>,
#  'イモ': <gensim.models.keyedvectors.Vocab at 0x10cadf908>,
#  'バナナ': <gensim.models.keyedvectors.Vocab at 0x10cadf940>,
#  '定住': <gensim.models.keyedvectors.Vocab at 0x10cadf978>,
#  '促し': <gensim.models.keyedvectors.Vocab at 0x10cadf9b0>,
#  '日干し': <gensim.models.keyedvectors.Vocab at 0x10cadf9e8>,
#  '煉瓦': <gensim.models.keyedvectors.Vocab at 0x10cadfa20>,
#  '家': <gensim.models.keyedvectors.Vocab at 0x10cadfa58>,
#  'なり': <gensim.models.keyedvectors.Vocab at 0x10cadfa90>,
#  '焼成': <gensim.models.keyedvectors.Vocab at 0x10cadfac8>,
#  '雨水': <gensim.models.keyedvectors.Vocab at 0x10cadfb00>,
#  'たより': <gensim.models.keyedvectors.Vocab at 0x10cadfb38>,
#  '肥料': <gensim.models.keyedvectors.Vocab at 0x10cadfb70>,
#  'ほどこさ': <gensim.models.keyedvectors.Vocab at 0x10cadfba8>,
#  '初期': <gensim.models.keyedvectors.Vocab at 0x10cadfbe0>,
#  '土壌': <gensim.models.keyedvectors.Vocab at 0x10cadfc18>,
#  '地力': <gensim.models.keyedvectors.Vocab at 0x10cadfc50>,
#  '依存': <gensim.models.keyedvectors.Vocab at 0x10cadfc88>,
#  '度': <gensim.models.keyedvectors.Vocab at 0x10cadfcc0>,
#  '高く': <gensim.models.keyedvectors.Vocab at 0x10cadfcf8>,
#  '低かっ': <gensim.models.keyedvectors.Vocab at 0x10cadfd30>,
#  '稲作': <gensim.models.keyedvectors.Vocab at 0x10cadfd68>,
#  '除け': <gensim.models.keyedvectors.Vocab at 0x10cadfda0>,
#  'しばしば': <gensim.models.keyedvectors.Vocab at 0x10cadfdd8>,
#  '耕地': <gensim.models.keyedvectors.Vocab at 0x10cadfe10>,
#  'かえ': <gensim.models.keyedvectors.Vocab at 0x10cadfe48>,
#  'なけれ': <gensim.models.keyedvectors.Vocab at 0x10cadfe80>,
#  'なら': <gensim.models.keyedvectors.Vocab at 0x10cadfeb8>,
#  '移転': <gensim.models.keyedvectors.Vocab at 0x10cadfef0>,
#  'くりかえさ': <gensim.models.keyedvectors.Vocab at 0x10cadff28>,
#  '集落': <gensim.models.keyedvectors.Vocab at 0x10cadff60>,
#  '規模': <gensim.models.keyedvectors.Vocab at 0x10cadff98>,
#  'それほど': <gensim.models.keyedvectors.Vocab at 0x10cadffd0>,
#  '都市': <gensim.models.keyedvectors.Vocab at 0x10cae3048>,
#  '成長': <gensim.models.keyedvectors.Vocab at 0x10cae3080>,
#  'いたら': <gensim.models.keyedvectors.Vocab at 0x10cae30b8>,
#  'ｃｕｌｔｕｒｅ': <gensim.models.keyedvectors.Vocab at 0x10cae30f0>,
#  'ｃｉｖｉｌｉｚａｔｉｏｎ': <gensim.models.keyedvectors.Vocab at 0x10cae3128>,
#  '人間': <gensim.models.keyedvectors.Vocab at 0x10cae3160>,
#  '野生': <gensim.models.keyedvectors.Vocab at 0x10cae3198>,
#  '採取': <gensim.models.keyedvectors.Vocab at 0x10cae31d0>,
#  '覚え': <gensim.models.keyedvectors.Vocab at 0x10cae3208>,
#  '創意': <gensim.models.keyedvectors.Vocab at 0x10cae3240>,
#  '工夫': <gensim.models.keyedvectors.Vocab at 0x10cae3278>,
#  '必要': <gensim.models.keyedvectors.Vocab at 0x10cae32b0>,
#  '英語': <gensim.models.keyedvectors.Vocab at 0x10cae32e8>,
#  'ａｇｒｉｃｕｌｔｕｒｅ': <gensim.models.keyedvectors.Vocab at 0x10cae3320>,
#  'ラテン語': <gensim.models.keyedvectors.Vocab at 0x10cae3358>,
#  'ａｇｅｒ': <gensim.models.keyedvectors.Vocab at 0x10cae3390>,
#  '土地': <gensim.models.keyedvectors.Vocab at 0x10cae33c8>,
#  'ｃｕｌｔｕｒａ': <gensim.models.keyedvectors.Vocab at 0x10cae3400>,
#  '培う': <gensim.models.keyedvectors.Vocab at 0x10cae3438>,
#  '組み': <gensim.models.keyedvectors.Vocab at 0x10cae3470>,
#  '合わさっ': <gensim.models.keyedvectors.Vocab at 0x10cae34a8>,
#  '造語': <gensim.models.keyedvectors.Vocab at 0x10cae34e0>,
#  '活動': <gensim.models.keyedvectors.Vocab at 0x10cae3518>,
#  '適し': <gensim.models.keyedvectors.Vocab at 0x10cae3550>,
#  'つくりだす': <gensim.models.keyedvectors.Vocab at 0x10cae3588>,
#  'それぞれ': <gensim.models.keyedvectors.Vocab at 0x10cae35c0>,
#  '固有': <gensim.models.keyedvectors.Vocab at 0x10cae35f8>,
#  '生まれる': <gensim.models.keyedvectors.Vocab at 0x10cae3630>,
#  '馬': <gensim.models.keyedvectors.Vocab at 0x10cae3668>,
#  '船': <gensim.models.keyedvectors.Vocab at 0x10cae36a0>,
#  '交通': <gensim.models.keyedvectors.Vocab at 0x10cae36d8>,
#  '手段': <gensim.models.keyedvectors.Vocab at 0x10cae3710>,
#  '孤立': <gensim.models.keyedvectors.Vocab at 0x10cae3748>,
#  '諸': <gensim.models.keyedvectors.Vocab at 0x10cae3780>,
#  '交流': <gensim.models.keyedvectors.Vocab at 0x10cae37b8>,
#  'おこる': <gensim.models.keyedvectors.Vocab at 0x10cae37f0>,
#  '結ぶ': <gensim.models.keyedvectors.Vocab at 0x10cae3828>,
#  '回路': <gensim.models.keyedvectors.Vocab at 0x10cae3860>,
#  '網': <gensim.models.keyedvectors.Vocab at 0x10cae3898>,
#  '目': <gensim.models.keyedvectors.Vocab at 0x10cae38d0>,
#  '結び目': <gensim.models.keyedvectors.Vocab at 0x10cae3908>,
#  '成立': <gensim.models.keyedvectors.Vocab at 0x10cae3940>,
#  '必ずしも': <gensim.models.keyedvectors.Vocab at 0x10cae3978>,
#  'わけ': <gensim.models.keyedvectors.Vocab at 0x10cae39b0>,
#  '人工': <gensim.models.keyedvectors.Vocab at 0x10cae39e8>,
#  'ｃｉｖｉｔａｓ': <gensim.models.keyedvectors.Vocab at 0x10cae3a20>,
#  '市民': <gensim.models.keyedvectors.Vocab at 0x10cae3a58>,
#  'ｃｉｖｅｓ': <gensim.models.keyedvectors.Vocab at 0x10cae3a90>,
#  '互いに': <gensim.models.keyedvectors.Vocab at 0x10cae3ac8>,
#  '協力': <gensim.models.keyedvectors.Vocab at 0x10cae3b00>,
#  '豊か': <gensim.models.keyedvectors.Vocab at 0x10cae3b38>,
#  '便宜': <gensim.models.keyedvectors.Vocab at 0x10cae3b70>,
#  'もたらす': <gensim.models.keyedvectors.Vocab at 0x10cae3ba8>,
#  'のりこえ': <gensim.models.keyedvectors.Vocab at 0x10cae3be0>,
#  '伝わっ': <gensim.models.keyedvectors.Vocab at 0x10cae3c18>,
#  'いく': <gensim.models.keyedvectors.Vocab at 0x10cae3c50>,
#  '伝播': <gensim.models.keyedvectors.Vocab at 0x10cae3c88>,
#  '左右': <gensim.models.keyedvectors.Vocab at 0x10cae3cc0>,
#  '共通': <gensim.models.keyedvectors.Vocab at 0x10cae3cf8>,
#  '圏': <gensim.models.keyedvectors.Vocab at 0x10cae3d30>,
#  '東': <gensim.models.keyedvectors.Vocab at 0x10cae3d68>,
#  'み': <gensim.models.keyedvectors.Vocab at 0x10cae3da0>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x10cae3dd8>,
#  '出る': <gensim.models.keyedvectors.Vocab at 0x10cae3e10>,
#  'ところ': <gensim.models.keyedvectors.Vocab at 0x10cae3e48>,
#  '意味': <gensim.models.keyedvectors.Vocab at 0x10cae3e80>,
#  '北東': <gensim.models.keyedvectors.Vocab at 0x10cae3eb8>,
#  '部': <gensim.models.keyedvectors.Vocab at 0x10cae3ef0>,
#  '広がり': <gensim.models.keyedvectors.Vocab at 0x10cae3f28>,
#  '陽光': <gensim.models.keyedvectors.Vocab at 0x10cae3f60>,
#  'あふれ': <gensim.models.keyedvectors.Vocab at 0x10cae3f98>,
#  '高温': <gensim.models.keyedvectors.Vocab at 0x10cae3fd0>,
#  '中心': <gensim.models.keyedvectors.Vocab at 0x10cae6048>,
#  '肥沃': <gensim.models.keyedvectors.Vocab at 0x10cae6080>,
#  '大河': <gensim.models.keyedvectors.Vocab at 0x10cae60b8>,
#  '流域': <gensim.models.keyedvectors.Vocab at 0x10cae60f0>,
#  '山岳': <gensim.models.keyedvectors.Vocab at 0x10cae6128>,
#  'めぐまれ': <gensim.models.keyedvectors.Vocab at 0x10cae6160>,
#  'メソポタミア': <gensim.models.keyedvectors.Vocab at 0x10cae6198>,
#  'エジプト': <gensim.models.keyedvectors.Vocab at 0x10cae61d0>,
#  '灌漑': <gensim.models.keyedvectors.Vocab at 0x10cae6208>,
#  '営ま': <gensim.models.keyedvectors.Vocab at 0x10cae6240>,
#  '青銅器': <gensim.models.keyedvectors.Vocab at 0x10cae6278>,
#  '千年紀': <gensim.models.keyedvectors.Vocab at 0x10cae62b0>,
#  '後半': <gensim.models.keyedvectors.Vocab at 0x10cae62e8>,
#  'セム': <gensim.models.keyedvectors.Vocab at 0x10cae6320>,
#  '語': <gensim.models.keyedvectors.Vocab at 0x10cae6358>,
#  '系': <gensim.models.keyedvectors.Vocab at 0x10cae6390>,
#  '姿': <gensim.models.keyedvectors.Vocab at 0x10cae63c8>,
#  'あらわし': <gensim.models.keyedvectors.Vocab at 0x10cae6400>,
#  '国家': <gensim.models.keyedvectors.Vocab at 0x10cae6438>,
#  '王国': <gensim.models.keyedvectors.Vocab at 0x10cae6470>,
#  'なし': <gensim.models.keyedvectors.Vocab at 0x10cae64a8>,
#  '強大': <gensim.models.keyedvectors.Vocab at 0x10cae64e0>,
#  '王権': <gensim.models.keyedvectors.Vocab at 0x10cae6518>,
#  '民衆': <gensim.models.keyedvectors.Vocab at 0x10cae6550>,
#  '支配': <gensim.models.keyedvectors.Vocab at 0x10cae6588>,
#  '通例': <gensim.models.keyedvectors.Vocab at 0x10cae65c0>,
#  '影響': <gensim.models.keyedvectors.Vocab at 0x10cae65f8>,
#  '海': <gensim.models.keyedvectors.Vocab at 0x10cae6630>,
#  'こえ': <gensim.models.keyedvectors.Vocab at 0x10cae6668>,
#  'エーゲ海': <gensim.models.keyedvectors.Vocab at 0x10cae66a0>,
#  '沿岸': <gensim.models.keyedvectors.Vocab at 0x10cae66d8>,
#  '地方': <gensim.models.keyedvectors.Vocab at 0x10cae6710>,
#  '島々': <gensim.models.keyedvectors.Vocab at 0x10cae6748>,
#  '及ぶ': <gensim.models.keyedvectors.Vocab at 0x10cae6780>,
#  'インド': <gensim.models.keyedvectors.Vocab at 0x10cae67b8>,
#  '族': <gensim.models.keyedvectors.Vocab at 0x10cae67f0>,
#  'あいつい': <gensim.models.keyedvectors.Vocab at 0x10cae6828>,
#  '南下': <gensim.models.keyedvectors.Vocab at 0x10cae6860>,
#  'き': <gensim.models.keyedvectors.Vocab at 0x10cae6898>,
#  '勢力': <gensim.models.keyedvectors.Vocab at 0x10cae68d0>,
#  'ひしめきあい': <gensim.models.keyedvectors.Vocab at 0x10cae6908>,
#  'めまぐるしい': <gensim.models.keyedvectors.Vocab at 0x10cae6940>,
#  '興亡': <gensim.models.keyedvectors.Vocab at 0x10cae6978>,
#  'つづい': <gensim.models.keyedvectors.Vocab at 0x10cae69b0>,
#  '両翼': <gensim.models.keyedvectors.Vocab at 0x10cae69e8>,
#  'はさま': <gensim.models.keyedvectors.Vocab at 0x10cae6a20>,
#  'シリア・パレスティナ': <gensim.models.keyedvectors.Vocab at 0x10cae6a58>,
#  '仲介': <gensim.models.keyedvectors.Vocab at 0x10cae6a90>,
#  '商業': <gensim.models.keyedvectors.Vocab at 0x10cae6ac8>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x10cae6b00>,
#  '活発': <gensim.models.keyedvectors.Vocab at 0x10cae6b38>,
#  '海上': <gensim.models.keyedvectors.Vocab at 0x10cae6b70>,
#  '海域': <gensim.models.keyedvectors.Vocab at 0x10cae6ba8>,
#  'フェニキア': <gensim.models.keyedvectors.Vocab at 0x10cae6be0>,
#  '全域': <gensim.models.keyedvectors.Vocab at 0x10cae6c18>,
#  'もたらさ': <gensim.models.keyedvectors.Vocab at 0x10cae6c50>,
#  'アラム': <gensim.models.keyedvectors.Vocab at 0x10cae6c88>,
#  '活躍': <gensim.models.keyedvectors.Vocab at 0x10cae6cc0>,
#  'イラン': <gensim.models.keyedvectors.Vocab at 0x10cae6cf8>,
#  '高原': <gensim.models.keyedvectors.Vocab at 0x10cae6d30>,
#  '中央アジア': <gensim.models.keyedvectors.Vocab at 0x10cae6d68>,
#  '及ん': <gensim.models.keyedvectors.Vocab at 0x10cae6da0>,
#  '拡大': <gensim.models.keyedvectors.Vocab at 0x10cae6dd8>,
#  'まず': <gensim.models.keyedvectors.Vocab at 0x10cae6e10>,
#  'アッ': <gensim.models.keyedvectors.Vocab at 0x10cae6e48>,
#  '帝国': <gensim.models.keyedvectors.Vocab at 0x10cae6e80>,
#  'ついで': <gensim.models.keyedvectors.Vocab at 0x10cae6eb8>,
#  'ペ': <gensim.models.keyedvectors.Vocab at 0x10cae6ef0>,
#  'ルシア': <gensim.models.keyedvectors.Vocab at 0x10cae6f28>,
#  '狭く': <gensim.models.keyedvectors.Vocab at 0x10cae6f60>,
#  '背後': <gensim.models.keyedvectors.Vocab at 0x10cae6f98>,
#  '山々': <gensim.models.keyedvectors.Vocab at 0x10cae6fd0>,
#  'きりたっ': <gensim.models.keyedvectors.Vocab at 0x10caea048>,
#  'ギリシア': <gensim.models.keyedvectors.Vocab at 0x10caea080>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x10caea0b8>,
#  '開花': <gensim.models.keyedvectors.Vocab at 0x10caea0f0>,
#  '数': <gensim.models.keyedvectors.Vocab at 0x10caea128>,
#  'にくかっ': <gensim.models.keyedvectors.Vocab at 0x10caea160>,
#  '社会': <gensim.models.keyedvectors.Vocab at 0x10caea198>,
#  'はぐくま': <gensim.models.keyedvectors.Vocab at 0x10caea1d0>,
#  '後世': <gensim.models.keyedvectors.Vocab at 0x10caea208>,
#  '西洋': <gensim.models.keyedvectors.Vocab at 0x10caea240>,
#  '及ぼし': <gensim.models.keyedvectors.Vocab at 0x10caea278>,
#  '古典': <gensim.models.keyedvectors.Vocab at 0x10caea2b0>,
#  'ヘレニズム': <gensim.models.keyedvectors.Vocab at 0x10caea2e8>,
#  'インダス': <gensim.models.keyedvectors.Vocab at 0x10caea320>,
#  '川': <gensim.models.keyedvectors.Vocab at 0x10caea358>,
#  'いたる': <gensim.models.keyedvectors.Vocab at 0x10caea390>,
#  '広がる': <gensim.models.keyedvectors.Vocab at 0x10caea3c8>,
#  '世紀': <gensim.models.keyedvectors.Vocab at 0x10caea400>,
#  '変遷': <gensim.models.keyedvectors.Vocab at 0x10caea438>,
#  'あつかう': <gensim.models.keyedvectors.Vocab at 0x10caea470>,
#  '物': <gensim.models.keyedvectors.Vocab at 0x10caea4a8>,
#  '増大': <gensim.models.keyedvectors.Vocab at 0x10caea4e0>,
#  '人口': <gensim.models.keyedvectors.Vocab at 0x10caea518>,
#  '増え': <gensim.models.keyedvectors.Vocab at 0x10caea550>,
#  '各': <gensim.models.keyedvectors.Vocab at 0x10caea588>,
#  '物資': <gensim.models.keyedvectors.Vocab at 0x10caea5c0>,
#  '交換': <gensim.models.keyedvectors.Vocab at 0x10caea5f8>,
#  'くりひろげ': <gensim.models.keyedvectors.Vocab at 0x10caea630>,
#  '商人': <gensim.models.keyedvectors.Vocab at 0x10caea668>,
#  '職人': <gensim.models.keyedvectors.Vocab at 0x10caea6a0>,
#  '拠点': <gensim.models.keyedvectors.Vocab at 0x10caea6d8>,
#  'おおよそ': <gensim.models.keyedvectors.Vocab at 0x10caea710>,
#  'ミレニアム': <gensim.models.keyedvectors.Vocab at 0x10caea748>,
#  '年間': <gensim.models.keyedvectors.Vocab at 0x10caea780>,
#  'いう': <gensim.models.keyedvectors.Vocab at 0x10caea7b8>,
#  '東方': <gensim.models.keyedvectors.Vocab at 0x10caea7f0>,
#  '古代': <gensim.models.keyedvectors.Vocab at 0x10caea828>,
#  'さす': <gensim.models.keyedvectors.Vocab at 0x10caea860>,
#  '城壁': <gensim.models.keyedvectors.Vocab at 0x10caea898>,
#  '囲ま': <gensim.models.keyedvectors.Vocab at 0x10caea8d0>,
#  '神殿': <gensim.models.keyedvectors.Vocab at 0x10caea908>,
#  '祭祀': <gensim.models.keyedvectors.Vocab at 0x10caea940>,
#  'つかさどる': <gensim.models.keyedvectors.Vocab at 0x10caea978>,
#  '神官': <gensim.models.keyedvectors.Vocab at 0x10caea9b0>,
#  '防衛': <gensim.models.keyedvectors.Vocab at 0x10caea9e8>,
#  '戦士': <gensim.models.keyedvectors.Vocab at 0x10caeaa20>,
#  'しだいに': <gensim.models.keyedvectors.Vocab at 0x10caeaa58>,
#  '強め': <gensim.models.keyedvectors.Vocab at 0x10caeaa90>,
#  '富': <gensim.models.keyedvectors.Vocab at 0x10caeaac8>,
#  '蓄え': <gensim.models.keyedvectors.Vocab at 0x10caeab00>,
#  '権力': <gensim.models.keyedvectors.Vocab at 0x10caeab38>,
#  '握っ': <gensim.models.keyedvectors.Vocab at 0x10caeab70>,
#  '階級': <gensim.models.keyedvectors.Vocab at 0x10caeaba8>,
#  '従属': <gensim.models.keyedvectors.Vocab at 0x10caeabe0>,
#  '分化': <gensim.models.keyedvectors.Vocab at 0x10caeac18>,
#  'おさめ': <gensim.models.keyedvectors.Vocab at 0x10caeac50>,
#  '金属': <gensim.models.keyedvectors.Vocab at 0x10caeac88>,
#  '当初': <gensim.models.keyedvectors.Vocab at 0x10caeacc0>,
#  '斧': <gensim.models.keyedvectors.Vocab at 0x10caeacf8>,
#  '刀剣': <gensim.models.keyedvectors.Vocab at 0x10caead30>,
#  '容器': <gensim.models.keyedvectors.Vocab at 0x10caead68>,
#  '装身具': <gensim.models.keyedvectors.Vocab at 0x10caeada0>,
#  '留針': <gensim.models.keyedvectors.Vocab at 0x10caeadd8>,
#  '神意': <gensim.models.keyedvectors.Vocab at 0x10caeae10>,
#  'うかがう': <gensim.models.keyedvectors.Vocab at 0x10caeae48>,
#  '財政': <gensim.models.keyedvectors.Vocab at 0x10caeae80>,
#  '会計': <gensim.models.keyedvectors.Vocab at 0x10caeaeb8>,
#  '事務': <gensim.models.keyedvectors.Vocab at 0x10caeaef0>,
#  'にとって': <gensim.models.keyedvectors.Vocab at 0x10caeaf28>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x10caeaf60>,
#  '誇示': <gensim.models.keyedvectors.Vocab at 0x10caeaf98>,
#  '美術': <gensim.models.keyedvectors.Vocab at 0x10caeafd0>,
#  '工芸': <gensim.models.keyedvectors.Vocab at 0x10caee048>,
#  '品': <gensim.models.keyedvectors.Vocab at 0x10caee080>,
#  'もてはやさ': <gensim.models.keyedvectors.Vocab at 0x10caee0b8>,
#  '融合': <gensim.models.keyedvectors.Vocab at 0x10caee0f0>,
#  '生みださ': <gensim.models.keyedvectors.Vocab at 0x10caee128>,
#  '伝え': <gensim.models.keyedvectors.Vocab at 0x10caee160>,
#  'ティグリス・ユーフラテス': <gensim.models.keyedvectors.Vocab at 0x10caee198>,
#  '両川': <gensim.models.keyedvectors.Vocab at 0x10caee1d0>,
#  '沖積': <gensim.models.keyedvectors.Vocab at 0x10caee208>,
#  '平野': <gensim.models.keyedvectors.Vocab at 0x10caee240>,
#  '村落': <gensim.models.keyedvectors.Vocab at 0x10caee278>,
#  'シュメール': <gensim.models.keyedvectors.Vocab at 0x10caee2b0>,
#  'ウルク': <gensim.models.keyedvectors.Vocab at 0x10caee2e8>,
#  'ウル': <gensim.models.keyedvectors.Vocab at 0x10caee320>,
#  'ラガシュ': <gensim.models.keyedvectors.Vocab at 0x10caee358>,
#  '残し': <gensim.models.keyedvectors.Vocab at 0x10caee390>,
#  '系統': <gensim.models.keyedvectors.Vocab at 0x10caee3c8>,
#  '不明': <gensim.models.keyedvectors.Vocab at 0x10caee400>,
#  '守護神': <gensim.models.keyedvectors.Vocab at 0x10caee438>,
#  'まつる': <gensim.models.keyedvectors.Vocab at 0x10caee470>,
#  'たち': <gensim.models.keyedvectors.Vocab at 0x10caee4a8>,
#  '神権': <gensim.models.keyedvectors.Vocab at 0x10caee4e0>,
#  '領土': <gensim.models.keyedvectors.Vocab at 0x10caee518>,
#  '路': <gensim.models.keyedvectors.Vocab at 0x10caee550>,
#  'をめぐって': <gensim.models.keyedvectors.Vocab at 0x10caee588>,
#  '争い': <gensim.models.keyedvectors.Vocab at 0x10caee5c0>,
#  '侵攻': <gensim.models.keyedvectors.Vocab at 0x10caee5f8>,
#  'だ': <gensim.models.keyedvectors.Vocab at 0x10caee630>,
#  '盛衰': <gensim.models.keyedvectors.Vocab at 0x10caee668>,
#  'くりかえし': <gensim.models.keyedvectors.Vocab at 0x10caee6a0>,
#  '基礎': <gensim.models.keyedvectors.Vocab at 0x10caee6d8>,
#  'なす': <gensim.models.keyedvectors.Vocab at 0x10caee710>,
#  '考え方': <gensim.models.keyedvectors.Vocab at 0x10caee748>,
#  '占星術': <gensim.models.keyedvectors.Vocab at 0x10caee780>,
#  '天体': <gensim.models.keyedvectors.Vocab at 0x10caee7b8>,
#  '観測': <gensim.models.keyedvectors.Vocab at 0x10caee7f0>,
#  '暦法': <gensim.models.keyedvectors.Vocab at 0x10caee828>,
#  '太陰暦': <gensim.models.keyedvectors.Vocab at 0x10caee860>,
#  'のち': <gensim.models.keyedvectors.Vocab at 0x10caee898>,
#  '閏月': <gensim.models.keyedvectors.Vocab at 0x10caee8d0>,
#  '加え': <gensim.models.keyedvectors.Vocab at 0x10caee908>,
#  '太陰': <gensim.models.keyedvectors.Vocab at 0x10caee940>,
#  '太陽暦': <gensim.models.keyedvectors.Vocab at 0x10caee978>,
#  '六': <gensim.models.keyedvectors.Vocab at 0x10caee9b0>,
#  '十進法': <gensim.models.keyedvectors.Vocab at 0x10caee9e8>,
#  '時間': <gensim.models.keyedvectors.Vocab at 0x10caeea20>,
#  '方位': <gensim.models.keyedvectors.Vocab at 0x10caeea58>,
#  '区分': <gensim.models.keyedvectors.Vocab at 0x10caeea90>,
#  '車軸': <gensim.models.keyedvectors.Vocab at 0x10caeeac8>,
#  'やろ': <gensim.models.keyedvectors.Vocab at 0x10caeeb00>,
#  'くろ': <gensim.models.keyedvectors.Vocab at 0x10caeeb38>,
#  '印章': <gensim.models.keyedvectors.Vocab at 0x10caeeb70>,
#  '絵文字': <gensim.models.keyedvectors.Vocab at 0x10caeeba8>,
#  '刻ま': <gensim.models.keyedvectors.Vocab at 0x10caeebe0>,
#  '楔形文字': <gensim.models.keyedvectors.Vocab at 0x10caeec18>,
#  '原型': <gensim.models.keyedvectors.Vocab at 0x10caeec50>,
#  '記さ': <gensim.models.keyedvectors.Vocab at 0x10caeec88>,
#  '粘土': <gensim.models.keyedvectors.Vocab at 0x10caeecc0>,
#  '板': <gensim.models.keyedvectors.Vocab at 0x10caeecf8>,
#  '発掘': <gensim.models.keyedvectors.Vocab at 0x10caeed30>,
#  '十': <gensim.models.keyedvectors.Vocab at 0x10caeed68>,
#  '点': <gensim.models.keyedvectors.Vocab at 0x10caeeda0>,
#  'のぼる': <gensim.models.keyedvectors.Vocab at 0x10caeedd8>,
#  '『': <gensim.models.keyedvectors.Vocab at 0x10caeee10>,
#  '旧約': <gensim.models.keyedvectors.Vocab at 0x10caeee48>,
#  '聖書': <gensim.models.keyedvectors.Vocab at 0x10caeee80>,
#  '』': <gensim.models.keyedvectors.Vocab at 0x10caeeeb8>,
#  'ノア': <gensim.models.keyedvectors.Vocab at 0x10caeeef0>,
#  '箱': <gensim.models.keyedvectors.Vocab at 0x10caeef28>,
#  '舟': <gensim.models.keyedvectors.Vocab at 0x10caeef60>,
#  '洪水': <gensim.models.keyedvectors.Vocab at 0x10caeef98>,
#  '説話': <gensim.models.keyedvectors.Vocab at 0x10caeefd0>,
#  'ふくむ': <gensim.models.keyedvectors.Vocab at 0x10caf1048>,
#  'ギルガメシュ': <gensim.models.keyedvectors.Vocab at 0x10caf1080>,
#  '物語': <gensim.models.keyedvectors.Vocab at 0x10caf10b8>,
#  '文芸': <gensim.models.keyedvectors.Vocab at 0x10caf10f0>,
#  '作品': <gensim.models.keyedvectors.Vocab at 0x10caf1128>,
#  '銀': <gensim.models.keyedvectors.Vocab at 0x10caf1160>,
#  '中ごろ': <gensim.models.keyedvectors.Vocab at 0x10caf1198>,
#  'アッカド': <gensim.models.keyedvectors.Vocab at 0x10caf11d0>,
#  'サルゴン': <gensim.models.keyedvectors.Vocab at 0x10caf1208>,
#  '世': <gensim.models.keyedvectors.Vocab at 0x10caf1240>,
#  '率い': <gensim.models.keyedvectors.Vocab at 0x10caf1278>,
#  '征服': <gensim.models.keyedvectors.Vocab at 0x10caf12b0>,
#  '覇権': <gensim.models.keyedvectors.Vocab at 0x10caf12e8>,
#  'ふるっ': <gensim.models.keyedvectors.Vocab at 0x10caf1320>,
#  '独立': <gensim.models.keyedvectors.Vocab at 0x10caf1358>,
#  '回復': <gensim.models.keyedvectors.Vocab at 0x10caf1390>,
#  '第': <gensim.models.keyedvectors.Vocab at 0x10caf13c8>,
#  '王朝': <gensim.models.keyedvectors.Vocab at 0x10caf1400>,
#  '繁栄': <gensim.models.keyedvectors.Vocab at 0x10caf1438>,
#  'アムル': <gensim.models.keyedvectors.Vocab at 0x10caf1470>,
#  '大挙': <gensim.models.keyedvectors.Vocab at 0x10caf14a8>,
#  'おしよせ': <gensim.models.keyedvectors.Vocab at 0x10caf14e0>,
#  'バビロン': <gensim.models.keyedvectors.Vocab at 0x10caf1518>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x10caf1550>,
#  'バビロニア': <gensim.models.keyedvectors.Vocab at 0x10caf1588>,
#  'ハンムラビ': <gensim.models.keyedvectors.Vocab at 0x10caf15c0>,
#  '王': <gensim.models.keyedvectors.Vocab at 0x10caf15f8>,
#  '全土': <gensim.models.keyedvectors.Vocab at 0x10caf1630>,
#  '慣習': <gensim.models.keyedvectors.Vocab at 0x10caf1668>,
#  '集大成': <gensim.models.keyedvectors.Vocab at 0x10caf16a0>,
#  '法典': <gensim.models.keyedvectors.Vocab at 0x10caf16d8>,
#  '発布': <gensim.models.keyedvectors.Vocab at 0x10caf1710>,
#  '前文': <gensim.models.keyedvectors.Vocab at 0x10caf1748>,
#  '条': <gensim.models.keyedvectors.Vocab at 0x10caf1780>,
#  '条文': <gensim.models.keyedvectors.Vocab at 0x10caf17b8>,
#  '後': <gensim.models.keyedvectors.Vocab at 0x10caf17f0>,
#  '刑法': <gensim.models.keyedvectors.Vocab at 0x10caf1828>,
#  '民法': <gensim.models.keyedvectors.Vocab at 0x10caf1860>,
#  '商法': <gensim.models.keyedvectors.Vocab at 0x10caf1898>,
#  '多方面': <gensim.models.keyedvectors.Vocab at 0x10caf18d0>,
#  '内容': <gensim.models.keyedvectors.Vocab at 0x10caf1908>,
#  '分野': <gensim.models.keyedvectors.Vocab at 0x10caf1940>,
#  '歯': <gensim.models.keyedvectors.Vocab at 0x10caf1978>,
#  '同': <gensim.models.keyedvectors.Vocab at 0x10caf19b0>,
#  '害': <gensim.models.keyedvectors.Vocab at 0x10caf19e8>,
#  '復讐': <gensim.models.keyedvectors.Vocab at 0x10caf1a20>,
#  '原則': <gensim.models.keyedvectors.Vocab at 0x10caf1a58>,
#  'とら': <gensim.models.keyedvectors.Vocab at 0x10caf1a90>,
#  '身分': <gensim.models.keyedvectors.Vocab at 0x10caf1ac8>,
#  '刑罰': <gensim.models.keyedvectors.Vocab at 0x10caf1b00>,
#  '差': <gensim.models.keyedvectors.Vocab at 0x10caf1b38>,
#  '特色': <gensim.models.keyedvectors.Vocab at 0x10caf1b70>,
#  '権威': <gensim.models.keyedvectors.Vocab at 0x10caf1ba8>,
#  'みなさ': <gensim.models.keyedvectors.Vocab at 0x10caf1be0>,
#  'ナイル': <gensim.models.keyedvectors.Vocab at 0x10caf1c18>,
#  '毎年': <gensim.models.keyedvectors.Vocab at 0x10caf1c50>,
#  '上流': <gensim.models.keyedvectors.Vocab at 0x10caf1c88>,
#  '域': <gensim.models.keyedvectors.Vocab at 0x10caf1cc0>,
#  '降雨': <gensim.models.keyedvectors.Vocab at 0x10caf1cf8>,
#  '増水': <gensim.models.keyedvectors.Vocab at 0x10caf1d30>,
#  '水': <gensim.models.keyedvectors.Vocab at 0x10caf1d68>,
#  '引く': <gensim.models.keyedvectors.Vocab at 0x10caf1da0>,
#  '残す': <gensim.models.keyedvectors.Vocab at 0x10caf1dd8>,
#  '賜物': <gensim.models.keyedvectors.Vocab at 0x10caf1e10>,
#  '多数': <gensim.models.keyedvectors.Vocab at 0x10caf1e48>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x10caf1e80>,
#  'ノ': <gensim.models.keyedvectors.Vocab at 0x10caf1eb8>,
#  'モス': <gensim.models.keyedvectors.Vocab at 0x10caf1ef0>,
#  'まとまっ': <gensim.models.keyedvectors.Vocab at 0x10caf1f28>,
#  '暮らし': <gensim.models.keyedvectors.Vocab at 0x10caf1f60>,
#  'ヘロドトス': <gensim.models.keyedvectors.Vocab at 0x10caf1f98>,
#  '言葉': <gensim.models.keyedvectors.Vocab at 0x10caf1fd0>,
#  'ノモス': <gensim.models.keyedvectors.Vocab at 0x10caf5048>,
#  '河谷': <gensim.models.keyedvectors.Vocab at 0x10caf5080>,
#  'デルタ': <gensim.models.keyedvectors.Vocab at 0x10caf50b8>,
#  '二つ': <gensim.models.keyedvectors.Vocab at 0x10caf50f0>,
#  'まとめ': <gensim.models.keyedvectors.Vocab at 0x10caf5128>,
#  '上下': <gensim.models.keyedvectors.Vocab at 0x10caf5160>,
#  '統一': <gensim.models.keyedvectors.Vocab at 0x10caf5198>,
#  'メンフィス': <gensim.models.keyedvectors.Vocab at 0x10caf51d0>,
#  'ファ': <gensim.models.keyedvectors.Vocab at 0x10caf5208>,
#  'ラオ': <gensim.models.keyedvectors.Vocab at 0x10caf5240>,
#  '家系': <gensim.models.keyedvectors.Vocab at 0x10caf5278>,
#  '交代': <gensim.models.keyedvectors.Vocab at 0x10caf52b0>,
#  '外部': <gensim.models.keyedvectors.Vocab at 0x10caf52e8>,
#  '強力': <gensim.models.keyedvectors.Vocab at 0x10caf5320>,
#  '誇り': <gensim.models.keyedvectors.Vocab at 0x10caf5358>,
#  '官僚': <gensim.models.keyedvectors.Vocab at 0x10caf5390>,
#  '制': <gensim.models.keyedvectors.Vocab at 0x10caf53c8>,
#  'おとろえ': <gensim.models.keyedvectors.Vocab at 0x10caf5400>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x10caf5438>,
#  ...}

# %%
model_ja.wv.most_similar(['東アジア'])
# Out:
# [('排出', 0.39770206809043884),
#  ('置', 0.3571590185165405),
#  ('法則', 0.34622806310653687),
#  ('マカオ', 0.34412676095962524),
#  ('離婚', 0.3395390212535858),
#  ('にまつわる', 0.3390005826950073),
#  ('以来', 0.3386876881122589),
#  ('車軸', 0.3382636308670044),
#  ('きわめ', 0.32996922731399536),
#  ('ネルヴァ', 0.32973313331604004)]

# %%
model_ja.init_sims(replace=True)

# %%
summary = 'カイロの中心は、ナイル川東岸にほど近いタハリール広場である。タハリール広場の周辺にはモガンマアと呼ばれる政府庁舎ビルや国民民主党本部、カイロ・アメリカン大学のキャンパスやエジプト考古学博物館、アラブ連盟本部ビルなどがあり、またカイロ地下鉄のターミナルであるサダト駅もこの地下にある。2011年エジプト騒乱においては、この広場に民衆が集結し、ホスニー・ムバーラク大統領の退陣を求める民主化デモの拠点となった。このあたりはカスル・アンニール地区と呼ばれる。タハリール広場から北東にはタラアト・ハルプ広場があり、この周辺からタラアト・ハルプ通りやカスル・アンニール通りにかけての一帯が繁華街となっている。その北東にはオスマン時代には湖であったところをムハンマド・アリー朝時代に埋め立てて作ったイズベキーヤ公園がある。さらにその北にはカイロの中央駅であるラムセス駅があり、ここからアレキサンドリアやデルタ各地、アスワンなど上エジプトに列車が走っている。また、タハリール広場から東に400mほどのところにムハンマド・アリー朝の王宮であり、現大統領府であるアブディーン宮殿がある。タハリール広場から南のナイル川沿いはガーデン・シティと呼ばれ、イギリス統治時代にエジプト総督府がおかれ開発が進められたエリアである。ガーデン・シティの名の通り、庭園に囲まれた高級住宅街が広がっている。このタハリール広場を中心とした地'

# %%
tokenized_summary = get_tokenized_line_ja(summary)

# %%
gold = '古代エジプトは、ナイル川を中心に長らく独立王朝が栄えたが、アレクサンドロス大王などの征服を受ける。プトレマイオス朝エジプトのクレオパトラは、地中海の覇権国であったローマの内乱に際し、アントニウスと連合してオクタヴィアヌスに対抗するが、アクティウムの海戦に敗れ、エジプトはローマの属州となった。紀元7世紀にアラビア半島を統一したイスラム教勢力は、東ローマ帝国とササン朝ペルシアの対立に乗じて版図を拡大し、エジプトを征服した。イスラム帝国の版図の一部を継承したファーティマ朝では、1196年にサラディンが宰相となり、イスラム教勢力から聖地エルサレムを奪還しようとする十字軍に対抗した。同じく、十字軍に対抗する中でエジプトに建てられたマムルーク朝は、オスマン帝国の侵攻を受けて滅ぶ。近代には、イギリス本国とインドとの連絡線を断つために、フランスのナポレオンがエジプトに進攻し、解放者を称するが、民衆の抵抗に遭った。対仏戦争に際して、オスマン帝国がエジプトに派遣したムハンマド・アリーは、同地に王朝を建てる。このムハンマド・アリー朝は、イギリスによる内政への介入を受けるようになり、その保護国となる。ナセルは、1952年に革命を起こして王政を倒し、イスラエルとの戦争を指導した。'

# %%
tokenized_gold = get_tokenized_line_ja(gold)

# %%
model_ja.wmdistance(tokenized_summary.split(), tokenized_gold.split())

# %%
model_ja.save('w2v_ja.model')

# %%
import os


def listdir_file_path(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

# %%
def yield_tokenized_en_wiki_lines(folder_path='qalab3-essay-phase2/enwiki_doc_by_id-tokenized'):
    for file_path in listdir_file_path(folder_path):
        with open(file_path) as f:
            for line in f:
                line = line.strip()
                if xml_tag_re.match(line):
                    continue
                if line.startswith('<Title>'):
                    line = line.replace('<Title>', '').replace('</Title>', '')
                yield line.split()

# %%
from itertools import chain


line_list_of_en_token_list = chain(yield_tokenized_en_wiki_lines())

# %%
model_en = get_w2v(line_list_of_en_token_list)

# %%
model_en.wv.vocab
# Out:
# {'Emil': <gensim.models.keyedvectors.Vocab at 0x110cee1d0>,
#  'Kraepelin': <gensim.models.keyedvectors.Vocab at 0x10ecf7438>,
#  '-LCB-': <gensim.models.keyedvectors.Vocab at 0x115789940>,
#  'Infobox': <gensim.models.keyedvectors.Vocab at 0x115789a20>,
#  'scientist': <gensim.models.keyedvectors.Vocab at 0x1157890f0>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x115789240>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x115789908>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x115789a90>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x115789080>,
#  '1926.jpg': <gensim.models.keyedvectors.Vocab at 0x115789358>,
#  'image_size': <gensim.models.keyedvectors.Vocab at 0x115789710>,
#  'alt': <gensim.models.keyedvectors.Vocab at 0x1157891d0>,
#  'caption': <gensim.models.keyedvectors.Vocab at 0x115789320>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x115789780>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1157898d0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x115789048>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x115789ac8>,
#  'birth_date': <gensim.models.keyedvectors.Vocab at 0x115789b00>,
#  'birth_place': <gensim.models.keyedvectors.Vocab at 0x115789b38>,
#  'Neustrelitz': <gensim.models.keyedvectors.Vocab at 0x115789b70>,
#  'death_date': <gensim.models.keyedvectors.Vocab at 0x115789ba8>,
#  'death_place': <gensim.models.keyedvectors.Vocab at 0x115789be0>,
#  'Munich': <gensim.models.keyedvectors.Vocab at 0x115789390>,
#  'resting_place': <gensim.models.keyedvectors.Vocab at 0x115789a58>,
#  'resting_place_coordinates': <gensim.models.keyedvectors.Vocab at 0x115789208>,
#  'residence': <gensim.models.keyedvectors.Vocab at 0x115789630>,
#  'citizenship': <gensim.models.keyedvectors.Vocab at 0x115789668>,
#  'German': <gensim.models.keyedvectors.Vocab at 0x1157896a0>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x1157896d8>,
#  'Psychiatry': <gensim.models.keyedvectors.Vocab at 0x115789400>,
#  'University': <gensim.models.keyedvectors.Vocab at 0x115789438>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x115789e80>,
#  'thesis_title': <gensim.models.keyedvectors.Vocab at 0x1157894e0>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x1157897b8>,
#  'Place': <gensim.models.keyedvectors.Vocab at 0x1157897f0>,
#  'Psychology': <gensim.models.keyedvectors.Vocab at 0x115789860>,
#  'thesis_url': <gensim.models.keyedvectors.Vocab at 0x115789898>,
#  'thesis_year': <gensim.models.keyedvectors.Vocab at 0x115789c18>,
#  'doctoral_advisor': <gensim.models.keyedvectors.Vocab at 0x115789e48>,
#  'academic_advisors': <gensim.models.keyedvectors.Vocab at 0x115789748>,
#  'doctoral_students': <gensim.models.keyedvectors.Vocab at 0x115789c50>,
#  'notable_students': <gensim.models.keyedvectors.Vocab at 0x115789c88>,
#  'known_for': <gensim.models.keyedvectors.Vocab at 0x115789cc0>,
#  'Classification': <gensim.models.keyedvectors.Vocab at 0x115789cf8>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x115789d30>,
#  'disorders': <gensim.models.keyedvectors.Vocab at 0x115789d68>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x115789dd8>,
#  'Kraepelinian': <gensim.models.keyedvectors.Vocab at 0x115789eb8>,
#  'dichotomy': <gensim.models.keyedvectors.Vocab at 0x115789198>,
#  'author_abbrev_bot': <gensim.models.keyedvectors.Vocab at 0x1157892b0>,
#  'author_abbrev_zoo': <gensim.models.keyedvectors.Vocab at 0x115789518>,
#  'influences': <gensim.models.keyedvectors.Vocab at 0x1157895c0>,
#  'Wilhelm': <gensim.models.keyedvectors.Vocab at 0x115789278>,
#  'Wundt': <gensim.models.keyedvectors.Vocab at 0x115789128>,
#  'Bernhard': <gensim.models.keyedvectors.Vocab at 0x115789978>,
#  'von': <gensim.models.keyedvectors.Vocab at 0x1157890b8>,
#  'Gudden': <gensim.models.keyedvectors.Vocab at 0x115789160>,
#  'Karl': <gensim.models.keyedvectors.Vocab at 0x115789470>,
#  'Ludwig': <gensim.models.keyedvectors.Vocab at 0x115789ef0>,
#  'Kahlbaum': <gensim.models.keyedvectors.Vocab at 0x115789f28>,
#  'influenced': <gensim.models.keyedvectors.Vocab at 0x115789f60>,
#  'Diagnostic': <gensim.models.keyedvectors.Vocab at 0x1157894a8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x115789f98>,
#  'Statistical': <gensim.models.keyedvectors.Vocab at 0x115789fd0>,
#  'Manual': <gensim.models.keyedvectors.Vocab at 0x115785630>,
#  'Mental': <gensim.models.keyedvectors.Vocab at 0x115785208>,
#  'Disorders': <gensim.models.keyedvectors.Vocab at 0x115785a90>,
#  'International': <gensim.models.keyedvectors.Vocab at 0x1157852e8>,
#  'Diseases': <gensim.models.keyedvectors.Vocab at 0x115785ac8>,
#  'Related': <gensim.models.keyedvectors.Vocab at 0x115785c88>,
#  'Health': <gensim.models.keyedvectors.Vocab at 0x1157854e0>,
#  'Problems': <gensim.models.keyedvectors.Vocab at 0x1157851d0>,
#  'awards': <gensim.models.keyedvectors.Vocab at 0x1157852b0>,
#  'signature': <gensim.models.keyedvectors.Vocab at 0x115785e10>,
#  'Emil_Kraepelin_signature.JPG': <gensim.models.keyedvectors.Vocab at 0x115785c18>,
#  'signature_alt': <gensim.models.keyedvectors.Vocab at 0x115782390>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x115782d30>,
#  'footnotes': <gensim.models.keyedvectors.Vocab at 0x115782470>,
#  'spouse': <gensim.models.keyedvectors.Vocab at 0x1157829b0>,
#  '-RCB-': <gensim.models.keyedvectors.Vocab at 0x115787470>,
#  'psychiatrist': <gensim.models.keyedvectors.Vocab at 0x1157874a8>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x1157874e0>,
#  'biological': <gensim.models.keyedvectors.Vocab at 0x115787550>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x115787588>,
#  'malfunction': <gensim.models.keyedvectors.Vocab at 0x1157875c0>,
#  'His': <gensim.models.keyedvectors.Vocab at 0x1157875f8>,
#  'theories': <gensim.models.keyedvectors.Vocab at 0x115787630>,
#  'dominated': <gensim.models.keyedvectors.Vocab at 0x115787668>,
#  'psychiatry': <gensim.models.keyedvectors.Vocab at 0x115787e80>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x115787908>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x115787160>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x115787828>,
#  'twentieth': <gensim.models.keyedvectors.Vocab at 0x115787128>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x115787860>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x1157871d0>,
#  'psychodynamic': <gensim.models.keyedvectors.Vocab at 0x115787240>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x115787be0>,
#  'Sigmund': <gensim.models.keyedvectors.Vocab at 0x115787eb8>,
#  'Freud': <gensim.models.keyedvectors.Vocab at 0x115787f28>,
#  'disciples': <gensim.models.keyedvectors.Vocab at 0x115787f60>,
#  'enjoyed': <gensim.models.keyedvectors.Vocab at 0x115787f98>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x115787fd0>,
#  'revival': <gensim.models.keyedvectors.Vocab at 0x115787748>,
#  'centurys': <gensim.models.keyedvectors.Vocab at 0x115787710>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1157876d8>,
#  '==': <gensim.models.keyedvectors.Vocab at 0x1157878d0>,
#  'Family': <gensim.models.keyedvectors.Vocab at 0x115787048>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x115787080>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1157870b8>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x115787ef0>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x1157872e8>,
#  'servant': <gensim.models.keyedvectors.Vocab at 0x115787358>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x115787390>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x1157873c8>,
#  '1856': <gensim.models.keyedvectors.Vocab at 0x1157876a0>,
#  'Duchy': <gensim.models.keyedvectors.Vocab at 0x115787cf8>,
#  'Mecklenburg-Strelitz': <gensim.models.keyedvectors.Vocab at 0x115787d30>,
#  'Germany': <gensim.models.keyedvectors.Vocab at 0x115787d68>,
#  'He': <gensim.models.keyedvectors.Vocab at 0x115787dd8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x115787e48>,
#  'introduced': <gensim.models.keyedvectors.Vocab at 0x115787278>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x115787c18>,
#  'biology': <gensim.models.keyedvectors.Vocab at 0x115787c50>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x115787c88>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x115787cc0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x110cd96d8>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x110cd9710>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x110cd9860>,
#  'Zoological': <gensim.models.keyedvectors.Vocab at 0x110cd9908>,
#  'Museum': <gensim.models.keyedvectors.Vocab at 0x110cd9780>,
#  'Hamburg': <gensim.models.keyedvectors.Vocab at 0x110cd98d0>,
#  'Career': <gensim.models.keyedvectors.Vocab at 0x110cd9748>,
#  'Leipzig': <gensim.models.keyedvectors.Vocab at 0x110cd9898>,
#  'Würzburg': <gensim.models.keyedvectors.Vocab at 0x110cd9940>,
#  'At': <gensim.models.keyedvectors.Vocab at 0x110cd9a58>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x110cd9ac8>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x110cd9c50>,
#  'neuropathology': <gensim.models.keyedvectors.Vocab at 0x110cd9c88>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x110cd9b00>,
#  'Paul': <gensim.models.keyedvectors.Vocab at 0x110cd9b38>,
#  'Flechsig': <gensim.models.keyedvectors.Vocab at 0x110cd9be0>,
#  'experimental': <gensim.models.keyedvectors.Vocab at 0x110cd9c18>,
#  'psychology': <gensim.models.keyedvectors.Vocab at 0x110cd9b70>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x110cd9ba8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x110cd9a90>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x110cd9978>,
#  'disciple': <gensim.models.keyedvectors.Vocab at 0x110cd9a20>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x110cd99b0>,
#  'lifelong': <gensim.models.keyedvectors.Vocab at 0x110cd99e8>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x110cd9cc0>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x110cd9cf8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x110cd9d30>,
#  'While': <gensim.models.keyedvectors.Vocab at 0x110cd9d68>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x110cd9da0>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x10a4d26a0>,
#  'prize-winning': <gensim.models.keyedvectors.Vocab at 0x10a4d25f8>,
#  'essay': <gensim.models.keyedvectors.Vocab at 0x10a4d2128>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x10a4d2320>,
#  'Influence': <gensim.models.keyedvectors.Vocab at 0x10a4d20b8>,
#  'Acute': <gensim.models.keyedvectors.Vocab at 0x10a4d21d0>,
#  'Illness': <gensim.models.keyedvectors.Vocab at 0x10a4d2278>,
#  'Causation': <gensim.models.keyedvectors.Vocab at 0x10a4d2668>,
#  "''": <gensim.models.keyedvectors.Vocab at 0x10a4d2400>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x10a4d23c8>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x10a4d2048>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x10a4d2198>,
#  '-LRB-': <gensim.models.keyedvectors.Vocab at 0x10a4d2358>,
#  'M.D.': <gensim.models.keyedvectors.Vocab at 0x10a4d2208>,
#  '-RRB-': <gensim.models.keyedvectors.Vocab at 0x10a4d24a8>,
#  '1878': <gensim.models.keyedvectors.Vocab at 0x10a4d20f0>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x10a4d22e8>,
#  '1879': <gensim.models.keyedvectors.Vocab at 0x10a4d2438>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x10a4d2390>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x10a4d2240>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x10a4d2630>,
#  'completed': <gensim.models.keyedvectors.Vocab at 0x10a4d22b0>,
#  'thesis': <gensim.models.keyedvectors.Vocab at 0x10ece3940>,
#  'Returning': <gensim.models.keyedvectors.Vocab at 0x10a4c7c50>,
#  '1882': <gensim.models.keyedvectors.Vocab at 0x10a4c7dd8>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x10a4c5b38>,
#  'Heinrich': <gensim.models.keyedvectors.Vocab at 0x10a4c59b0>,
#  'Erbs': <gensim.models.keyedvectors.Vocab at 0x10a4c5ac8>,
#  'neurology': <gensim.models.keyedvectors.Vocab at 0x1157877f0>,
#  'clinic': <gensim.models.keyedvectors.Vocab at 0x115787978>,
#  'Wundts': <gensim.models.keyedvectors.Vocab at 0x1157879b0>,
#  'psychopharmacology': <gensim.models.keyedvectors.Vocab at 0x1157879e8>,
#  'laboratory': <gensim.models.keyedvectors.Vocab at 0x115787a58>,
#  'Margaret': <gensim.models.keyedvectors.Vocab at 0x115787a90>,
#  'Alic': <gensim.models.keyedvectors.Vocab at 0x115787ac8>,
#  'Gale': <gensim.models.keyedvectors.Vocab at 0x115787b00>,
#  'Encyclopedia': <gensim.models.keyedvectors.Vocab at 0x115787b38>,
#  '2001': <gensim.models.keyedvectors.Vocab at 0x115787b70>,
#  'Kraepelins': <gensim.models.keyedvectors.Vocab at 0x115787ba8>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1157872b0>,
#  'Compendium': <gensim.models.keyedvectors.Vocab at 0x115787940>,
#  'der': <gensim.models.keyedvectors.Vocab at 0x115784e10>,
#  'Psychiatrie': <gensim.models.keyedvectors.Vocab at 0x115784e48>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x115784d68>,
#  '1883': <gensim.models.keyedvectors.Vocab at 0x115784d30>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x115784cc0>,
#  'argued': <gensim.models.keyedvectors.Vocab at 0x115784cf8>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x115784748>,
#  'branch': <gensim.models.keyedvectors.Vocab at 0x115784a58>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x115784908>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x115784978>,
#  'investigated': <gensim.models.keyedvectors.Vocab at 0x115784c18>,
#  'observation': <gensim.models.keyedvectors.Vocab at 0x115784c50>,
#  'experimentation': <gensim.models.keyedvectors.Vocab at 0x1157849b0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1157846d8>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x115784438>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x115784a90>,
#  'sciences': <gensim.models.keyedvectors.Vocab at 0x115784358>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x115784b70>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1157847f0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x115784320>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x1157844e0>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x115784780>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x115784080>,
#  'illness': <gensim.models.keyedvectors.Vocab at 0x115784f98>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x1157844a8>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x1157847b8>,
#  'foundations': <gensim.models.keyedvectors.Vocab at 0x115784eb8>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1157841d0>,
#  'classification': <gensim.models.keyedvectors.Vocab at 0x115784940>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x115784208>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x115784240>,
#  'studying': <gensim.models.keyedvectors.Vocab at 0x115784278>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1157842b0>,
#  'histories': <gensim.models.keyedvectors.Vocab at 0x115784b00>,
#  'identifying': <gensim.models.keyedvectors.Vocab at 0x115784ef0>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x115784588>,
#  'progression': <gensim.models.keyedvectors.Vocab at 0x1157845c0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x115784518>,
#  'predicted': <gensim.models.keyedvectors.Vocab at 0x115784e80>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1157840f0>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x115784198>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x115784128>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x115784828>,
#  'differences': <gensim.models.keyedvectors.Vocab at 0x1157848d0>,
#  'personality': <gensim.models.keyedvectors.Vocab at 0x115784668>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x1157846a0>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x115784ba8>,
#  'onset': <gensim.models.keyedvectors.Vocab at 0x115784be0>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x11578a860>,
#  'Clinic': <gensim.models.keyedvectors.Vocab at 0x11578a898>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x11578a8d0>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x11578a908>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x11578a940>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x11578a978>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x11578a9b0>,
#  'clinical': <gensim.models.keyedvectors.Vocab at 0x11578a9e8>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x11578aa20>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x11578aa58>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x11578aa90>,
#  'importance': <gensim.models.keyedvectors.Vocab at 0x11578aac8>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x11578ab00>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x11578ab38>,
#  '1903': <gensim.models.keyedvectors.Vocab at 0x11578ab70>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x11578aba8>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x11578abe0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x11578ac18>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x11578ac50>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x11578ac88>,
#  'Professor': <gensim.models.keyedvectors.Vocab at 0x11578acc0>,
#  'Clinical': <gensim.models.keyedvectors.Vocab at 0x11578acf8>,
#  'elected': <gensim.models.keyedvectors.Vocab at 0x11578ad30>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x11578ada0>,
#  'Royal': <gensim.models.keyedvectors.Vocab at 0x11578add8>,
#  'Swedish': <gensim.models.keyedvectors.Vocab at 0x11578ae10>,
#  'Academy': <gensim.models.keyedvectors.Vocab at 0x11578ae48>,
#  'Sciences': <gensim.models.keyedvectors.Vocab at 0x11578ae80>,
#  '1908': <gensim.models.keyedvectors.Vocab at 0x11578aeb8>,
#  'Institute': <gensim.models.keyedvectors.Vocab at 0x11578a048>,
#  'Psychiatric': <gensim.models.keyedvectors.Vocab at 0x11578a080>,
#  'Research': <gensim.models.keyedvectors.Vocab at 0x11578a0b8>,
#  'founded': <gensim.models.keyedvectors.Vocab at 0x11578a0f0>,
#  '1917': <gensim.models.keyedvectors.Vocab at 0x11578a128>,
#  'Initially': <gensim.models.keyedvectors.Vocab at 0x11578a160>,
#  'housed': <gensim.models.keyedvectors.Vocab at 0x11578a198>,
#  'existing': <gensim.models.keyedvectors.Vocab at 0x11578a1d0>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x11578a208>,
#  'buildings': <gensim.models.keyedvectors.Vocab at 0x11578a240>,
#  'maintained': <gensim.models.keyedvectors.Vocab at 0x11578a278>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x11578a2b0>,
#  'donations': <gensim.models.keyedvectors.Vocab at 0x11578a2e8>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x11578a320>,
#  'Loeb': <gensim.models.keyedvectors.Vocab at 0x11578a358>,
#  'relatives': <gensim.models.keyedvectors.Vocab at 0x11578a390>,
#  '1924': <gensim.models.keyedvectors.Vocab at 0x11578a3c8>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x11578a400>,
#  'auspices': <gensim.models.keyedvectors.Vocab at 0x11578a438>,
#  'Kaiser': <gensim.models.keyedvectors.Vocab at 0x11578a470>,
#  'Society': <gensim.models.keyedvectors.Vocab at 0x11578a4a8>,
#  'Advancement': <gensim.models.keyedvectors.Vocab at 0x11578a4e0>,
#  'Science': <gensim.models.keyedvectors.Vocab at 0x11578a518>,
#  'American': <gensim.models.keyedvectors.Vocab at 0x11578a550>,
#  'Rockefeller': <gensim.models.keyedvectors.Vocab at 0x11578a588>,
#  'familys': <gensim.models.keyedvectors.Vocab at 0x11578a5c0>,
#  'Foundation': <gensim.models.keyedvectors.Vocab at 0x11578a5f8>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x11578a630>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x11578a668>,
#  'donation': <gensim.models.keyedvectors.Vocab at 0x11578a6a0>,
#  'enabling': <gensim.models.keyedvectors.Vocab at 0x11578a6d8>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x11578a710>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x11578a748>,
#  'dedicated': <gensim.models.keyedvectors.Vocab at 0x11578a780>,
#  'building': <gensim.models.keyedvectors.Vocab at 0x11578a7b8>,
#  'institute': <gensim.models.keyedvectors.Vocab at 0x11578a7f0>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x11578a828>,
#  'guidelines': <gensim.models.keyedvectors.Vocab at 0x11578aef0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x11578af28>,
#  'officially': <gensim.models.keyedvectors.Vocab at 0x11578af60>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x11578af98>,
#  '1928': <gensim.models.keyedvectors.Vocab at 0x11578afd0>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x11578b7f0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x11578b080>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x11578b0b8>,
#  'barbarous': <gensim.models.keyedvectors.Vocab at 0x11578b128>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x11578b160>,
#  'prevalent': <gensim.models.keyedvectors.Vocab at 0x11578b1d0>,
#  'psychiatric': <gensim.models.keyedvectors.Vocab at 0x11578b208>,
#  'asylums': <gensim.models.keyedvectors.Vocab at 0x11578b278>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x11578b2b0>,
#  'crusaded': <gensim.models.keyedvectors.Vocab at 0x11578b320>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x11578b358>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x11578b3c8>,
#  'punishment': <gensim.models.keyedvectors.Vocab at 0x11578b400>,
#  'imprisonment': <gensim.models.keyedvectors.Vocab at 0x11578b438>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x11578b470>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x11578b4a8>,
#  'insane': <gensim.models.keyedvectors.Vocab at 0x11578b4e0>,
#  'rejected': <gensim.models.keyedvectors.Vocab at 0x11578b518>,
#  'psychoanalytical': <gensim.models.keyedvectors.Vocab at 0x11578b550>,
#  'posited': <gensim.models.keyedvectors.Vocab at 0x11578b588>,
#  'innate': <gensim.models.keyedvectors.Vocab at 0x11578b5c0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x11578b5f8>,
#  'sexuality': <gensim.models.keyedvectors.Vocab at 0x11578b668>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x11578b6a0>,
#  'philosophical': <gensim.models.keyedvectors.Vocab at 0x11578b6d8>,
#  'speculation': <gensim.models.keyedvectors.Vocab at 0x11578b710>,
#  'unscientific': <gensim.models.keyedvectors.Vocab at 0x11578b748>,
#  'focused': <gensim.models.keyedvectors.Vocab at 0x11578b780>,
#  'collecting': <gensim.models.keyedvectors.Vocab at 0x11578b7b8>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x11578b828>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x11578b860>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x11578b898>,
#  'e.g.': <gensim.models.keyedvectors.Vocab at 0x11578b8d0>,
#  'diseased': <gensim.models.keyedvectors.Vocab at 0x11578b908>,
#  'tissue': <gensim.models.keyedvectors.Vocab at 0x11578b940>,
#  'retired': <gensim.models.keyedvectors.Vocab at 0x11578b978>,
#  'teaching': <gensim.models.keyedvectors.Vocab at 0x11578b9b0>,
#  '66': <gensim.models.keyedvectors.Vocab at 0x11578b9e8>,
#  'spending': <gensim.models.keyedvectors.Vocab at 0x11578ba20>,
#  'remaining': <gensim.models.keyedvectors.Vocab at 0x11578ba58>,
#  'establishing': <gensim.models.keyedvectors.Vocab at 0x11578ba90>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x11578bac8>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x11578bb00>,
#  'Textbook': <gensim.models.keyedvectors.Vocab at 0x11578bb38>,
#  '1927': <gensim.models.keyedvectors.Vocab at 0x11578bb70>,
#  'shortly': <gensim.models.keyedvectors.Vocab at 0x11578bba8>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x11578bbe0>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x11578bc18>,
#  'comprised': <gensim.models.keyedvectors.Vocab at 0x11578bc50>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x11578bc88>,
#  'volumes': <gensim.models.keyedvectors.Vocab at 0x11578bcc0>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x11578bcf8>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x11578bd30>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x11578bd68>,
#  'Theories': <gensim.models.keyedvectors.Vocab at 0x11578bda0>,
#  'schemes': <gensim.models.keyedvectors.Vocab at 0x11578bdd8>,
#  'announced': <gensim.models.keyedvectors.Vocab at 0x11578be10>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x11578be48>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x11578be80>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x11578beb8>,
#  'referring': <gensim.models.keyedvectors.Vocab at 0x11578bef0>,
#  'traditional': <gensim.models.keyedvectors.Vocab at 0x11578bf28>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x11578bf60>,
#  'symptomatic': <gensim.models.keyedvectors.Vocab at 0x11578bf98>,
#  'This': <gensim.models.keyedvectors.Vocab at 0x11578bfd0>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x110dbd048>,
#  'paradigm-setting': <gensim.models.keyedvectors.Vocab at 0x110dbd080>,
#  'synthesis': <gensim.models.keyedvectors.Vocab at 0x110dbd0b8>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x110dbd0f0>,
#  'classified': <gensim.models.keyedvectors.Vocab at 0x110dbd128>,
#  '19th': <gensim.models.keyedvectors.Vocab at 0x110dbd160>,
#  'grouping': <gensim.models.keyedvectors.Vocab at 0x110dbd198>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x110dbd1d0>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x110dbd208>,
#  'syndrome': <gensim.models.keyedvectors.Vocab at 0x110dbd240>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x110dbd278>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x110dbd2b0>,
#  'patterns': <gensim.models.keyedvectors.Vocab at 0x110dbd2e8>,
#  'symptoms': <gensim.models.keyedvectors.Vocab at 0x110dbd320>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x110dbd358>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x110dbd390>,
#  'similarity': <gensim.models.keyedvectors.Vocab at 0x110dbd3c8>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x110dbd400>,
#  'predecessors': <gensim.models.keyedvectors.Vocab at 0x110dbd438>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x110dbd470>,
#  '5th': <gensim.models.keyedvectors.Vocab at 0x110dbd4a8>,
#  'textbook': <gensim.models.keyedvectors.Vocab at 0x110dbd4e0>,
#  'decisive': <gensim.models.keyedvectors.Vocab at 0x110dbd518>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x110dbd550>,
#  'insanity': <gensim.models.keyedvectors.Vocab at 0x110dbd588>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x110dbd5c0>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x110dbd5f8>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x110dbd630>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x110dbd668>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x110dbd6a0>,
#  'subordinated': <gensim.models.keyedvectors.Vocab at 0x110dbd6d8>,
#  'consideration': <gensim.models.keyedvectors.Vocab at 0x110dbd710>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x110dbd748>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x110dbd780>,
#  'terminus': <gensim.models.keyedvectors.Vocab at 0x110dbd7b8>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x110dbd7f0>,
#  'Thus': <gensim.models.keyedvectors.Vocab at 0x110dbd828>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x110dbd860>,
#  'purely': <gensim.models.keyedvectors.Vocab at 0x110dbd898>,
#  'categories': <gensim.models.keyedvectors.Vocab at 0x110dbd8d0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x110dbd908>,
#  'disappeared': <gensim.models.keyedvectors.Vocab at 0x110dbd940>,
#  'nosology': <gensim.models.keyedvectors.Vocab at 0x110dbd978>,
#  '===': <gensim.models.keyedvectors.Vocab at 0x110dbd9b0>,
#  'Psychosis': <gensim.models.keyedvectors.Vocab at 0x110dbd9e8>,
#  'mood': <gensim.models.keyedvectors.Vocab at 0x110dbda20>,
#  'unitary': <gensim.models.keyedvectors.Vocab at 0x110dbda58>,
#  'concept': <gensim.models.keyedvectors.Vocab at 0x110dbda90>,
#  'psychosis': <gensim.models.keyedvectors.Vocab at 0x110dbdac8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x110dbdb00>,
#  'distinct': <gensim.models.keyedvectors.Vocab at 0x110dbdb38>,
#  'forms': <gensim.models.keyedvectors.Vocab at 0x110dbdb70>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x110dbdba8>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x110dbdbe0>,
#  'manic': <gensim.models.keyedvectors.Vocab at 0x110dbdc18>,
#  'depression': <gensim.models.keyedvectors.Vocab at 0x110dbdc50>,
#  'recurrent': <gensim.models.keyedvectors.Vocab at 0x110dbdc88>,
#  'bipolar': <gensim.models.keyedvectors.Vocab at 0x110dbdcc0>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x110dbdcf8>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x110dbdd30>,
#  'dementia': <gensim.models.keyedvectors.Vocab at 0x110dbdd68>,
#  'praecox': <gensim.models.keyedvectors.Vocab at 0x110dbdda0>,
#  'Drawing': <gensim.models.keyedvectors.Vocab at 0x110dbddd8>,
#  'long-term': <gensim.models.keyedvectors.Vocab at 0x110dbde10>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x110dbde48>,
#  'criteria': <gensim.models.keyedvectors.Vocab at 0x110dbde80>,
#  'outcome': <gensim.models.keyedvectors.Vocab at 0x110dbdeb8>,
#  'prognosis': <gensim.models.keyedvectors.Vocab at 0x110dbdef0>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x110dbdf28>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x110dbdf60>,
#  'sub-acute': <gensim.models.keyedvectors.Vocab at 0x110dbdf98>,
#  'peculiar': <gensim.models.keyedvectors.Vocab at 0x110dbdfd0>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x110dc1048>,
#  'weakness': <gensim.models.keyedvectors.Vocab at 0x110dc1080>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x110dc10b8>,
#  'youthful': <gensim.models.keyedvectors.Vocab at 0x110dc10f0>,
#  'When': <gensim.models.keyedvectors.Vocab at 0x110dc1128>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x110dc1160>,
#  'diagnostic': <gensim.models.keyedvectors.Vocab at 0x110dc1198>,
#  'entity': <gensim.models.keyedvectors.Vocab at 0x110dc11d0>,
#  'fourth': <gensim.models.keyedvectors.Vocab at 0x110dc1208>,
#  'Lehrbuch': <gensim.models.keyedvectors.Vocab at 0x110dc1240>,
#  '1893': <gensim.models.keyedvectors.Vocab at 0x110dc1278>,
#  'placed': <gensim.models.keyedvectors.Vocab at 0x110dc12b0>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x110dc12e8>,
#  'degenerative': <gensim.models.keyedvectors.Vocab at 0x110dc1320>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x110dc1358>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x110dc1390>,
#  'separate': <gensim.models.keyedvectors.Vocab at 0x110dc13c8>,
#  'catatonia': <gensim.models.keyedvectors.Vocab at 0x110dc1400>,
#  'paranoides': <gensim.models.keyedvectors.Vocab at 0x110dc1438>,
#  'corresponded': <gensim.models.keyedvectors.Vocab at 0x110dc1470>,
#  'Ewald': <gensim.models.keyedvectors.Vocab at 0x110dc14a8>,
#  'Heckers': <gensim.models.keyedvectors.Vocab at 0x110dc14e0>,
#  'hebephrenia': <gensim.models.keyedvectors.Vocab at 0x110dc1518>,
#  'sixth': <gensim.models.keyedvectors.Vocab at 0x110dc1550>,
#  '1899': <gensim.models.keyedvectors.Vocab at 0x110dc1588>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x110dc15c0>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x110dc15f8>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x110dc1630>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x110dc1668>,
#  'treated': <gensim.models.keyedvectors.Vocab at 0x110dc16a0>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x110dc16d8>,
#  'expressions': <gensim.models.keyedvectors.Vocab at 0x110dc1710>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x110dc1748>,
#  'One': <gensim.models.keyedvectors.Vocab at 0x110dc1780>,
#  'cardinal': <gensim.models.keyedvectors.Vocab at 0x110dc17b8>,
#  'principles': <gensim.models.keyedvectors.Vocab at 0x110dc17f0>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x110dc1828>,
#  'recognition': <gensim.models.keyedvectors.Vocab at 0x110dc1860>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x110dc1898>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x110dc18d0>,
#  'symptom': <gensim.models.keyedvectors.Vocab at 0x110dc1908>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x110dc1940>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x110dc1978>,
#  'virtually': <gensim.models.keyedvectors.Vocab at 0x110dc19b0>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x110dc19e8>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x110dc1a20>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x110dc1a58>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x110dc1a90>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x110dc1ac8>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x110dc1b00>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x110dc1b38>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x110dc1b70>,
#  'manic-depression': <gensim.models.keyedvectors.Vocab at 0x110dc1ba8>,
#  'What': <gensim.models.keyedvectors.Vocab at 0x110dc1be0>,
#  'distinguishes': <gensim.models.keyedvectors.Vocab at 0x110dc1c18>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x110dc1c50>,
#  'symptomatically': <gensim.models.keyedvectors.Vocab at 0x110dc1c88>,
#  'opposed': <gensim.models.keyedvectors.Vocab at 0x110dc1cc0>,
#  'underlying': <gensim.models.keyedvectors.Vocab at 0x110dc1cf8>,
#  'pathology': <gensim.models.keyedvectors.Vocab at 0x110dc1d30>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x110dc1d68>,
#  'pathognomonic': <gensim.models.keyedvectors.Vocab at 0x110dc1da0>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x110dc1dd8>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x110dc1e10>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x110dc1e48>,
#  'physiological': <gensim.models.keyedvectors.Vocab at 0x110dc1e80>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x110dc1eb8>,
#  'marker': <gensim.models.keyedvectors.Vocab at 0x110dc1ef0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x110dc1f28>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x110dc1f60>,
#  'distinguish': <gensim.models.keyedvectors.Vocab at 0x110dc1f98>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x110dc1fd0>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x110dc4048>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x110dc4080>,
#  'demonstrated': <gensim.models.keyedvectors.Vocab at 0x110dc40b8>,
#  'genetics': <gensim.models.keyedvectors.Vocab at 0x110dc40f0>,
#  'characteristic': <gensim.models.keyedvectors.Vocab at 0x110dc4128>,
#  'Generally': <gensim.models.keyedvectors.Vocab at 0x110dc4160>,
#  'speaking': <gensim.models.keyedvectors.Vocab at 0x110dc4198>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x110dc41d0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x110dc4208>,
#  'schizophrenics': <gensim.models.keyedvectors.Vocab at 0x110dc4240>,
#  'schizophrenic': <gensim.models.keyedvectors.Vocab at 0x110dc4278>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x110dc42b0>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x110dc42e8>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x110dc4320>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x110dc4358>,
#  'frequent': <gensim.models.keyedvectors.Vocab at 0x110dc4390>,
#  'manic-depressives': <gensim.models.keyedvectors.Vocab at 0x110dc43c8>,
#  'Though': <gensim.models.keyedvectors.Vocab at 0x110dc4400>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x110dc4438>,
#  'demonstrate': <gensim.models.keyedvectors.Vocab at 0x110dc4470>,
#  'linkage': <gensim.models.keyedvectors.Vocab at 0x110dc44a8>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x110dc44e0>,
#  'socio-environmental': <gensim.models.keyedvectors.Vocab at 0x110dc4518>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x110dc4550>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x110dc4588>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x110dc45c0>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x110dc45f8>,
#  'schizophrenia': <gensim.models.keyedvectors.Vocab at 0x110dc4630>,
#  'deteriorating': <gensim.models.keyedvectors.Vocab at 0x110dc4668>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x110dc46a0>,
#  'continuously': <gensim.models.keyedvectors.Vocab at 0x110dc46d8>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x110dc4710>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x110dc4748>,
#  'erratically': <gensim.models.keyedvectors.Vocab at 0x110dc4780>,
#  'declines': <gensim.models.keyedvectors.Vocab at 0x110dc47b8>,
#  'manic-depressive': <gensim.models.keyedvectors.Vocab at 0x110dc47f0>,
#  'experienced': <gensim.models.keyedvectors.Vocab at 0x110dc4828>,
#  'intermittent': <gensim.models.keyedvectors.Vocab at 0x110dc4860>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x110dc4898>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x110dc48d0>,
#  'symptom-free': <gensim.models.keyedvectors.Vocab at 0x110dc4908>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x110dc4940>,
#  'intervals': <gensim.models.keyedvectors.Vocab at 0x110dc4978>,
#  'acute': <gensim.models.keyedvectors.Vocab at 0x110dc49b0>,
#  'episodes': <gensim.models.keyedvectors.Vocab at 0x110dc49e8>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x110dc4a20>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x110dc4a58>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x110dc4a90>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x110dc4ac8>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x110dc4b00>,
#  'signifying': <gensim.models.keyedvectors.Vocab at 0x110dc4b38>,
#  'irreversible': <gensim.models.keyedvectors.Vocab at 0x110dc4b70>,
#  'decline': <gensim.models.keyedvectors.Vocab at 0x110dc4ba8>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x110dc4be0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x110dc4c18>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x110dc4c50>,
#  'necessarily': <gensim.models.keyedvectors.Vocab at 0x110dc4c88>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x110dc4cc0>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x110dc4cf8>,
#  'renamed': <gensim.models.keyedvectors.Vocab at 0x110dc4d30>,
#  'Eugen': <gensim.models.keyedvectors.Vocab at 0x110dc4d68>,
#  'Bleuler': <gensim.models.keyedvectors.Vocab at 0x110dc4da0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x110dc4dd8>,
#  'misnomer': <gensim.models.keyedvectors.Vocab at 0x110dc4e10>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x110dc4e48>,
#  'accepted': <gensim.models.keyedvectors.Vocab at 0x110dc4e80>,
#  '1920': <gensim.models.keyedvectors.Vocab at 0x110dc4eb8>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x110dc4ef0>,
#  'increasingly': <gensim.models.keyedvectors.Vocab at 0x110dc4f28>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x110dc4f60>,
#  'satisfactorily': <gensim.models.keyedvectors.Vocab at 0x110dc4f98>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x110dc4fd0>,
#  'On': <gensim.models.keyedvectors.Vocab at 0x110dc8048>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x110dc8080>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x110dc80b8>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x110dc80f0>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x110dc8128>,
#  'cortical': <gensim.models.keyedvectors.Vocab at 0x110dc8160>,
#  'lesions': <gensim.models.keyedvectors.Vocab at 0x110dc8198>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x110dc81d0>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x110dc8208>,
#  'intact': <gensim.models.keyedvectors.Vocab at 0x110dc8240>,
#  'Nevertheless': <gensim.models.keyedvectors.Vocab at 0x110dc8278>,
#  'overlap': <gensim.models.keyedvectors.Vocab at 0x110dc82b0>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x110dc82e8>,
#  'diagnoses': <gensim.models.keyedvectors.Vocab at 0x110dc8320>,
#  'neurological': <gensim.models.keyedvectors.Vocab at 0x110dc8358>,
#  'abnormalities': <gensim.models.keyedvectors.Vocab at 0x110dc8390>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x110dc83c8>,
#  'continued': <gensim.models.keyedvectors.Vocab at 0x110dc8400>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x110dc8438>,
#  'category': <gensim.models.keyedvectors.Vocab at 0x110dc8470>,
#  'schizoaffective': <gensim.models.keyedvectors.Vocab at 0x110dc84a8>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x110dc84e0>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x110dc8518>,
#  'intermediate': <gensim.models.keyedvectors.Vocab at 0x110dc8550>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x110dc8588>,
#  'devoted': <gensim.models.keyedvectors.Vocab at 0x110dc85c0>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x110dc85f8>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x110dc8630>,
#  'pages': <gensim.models.keyedvectors.Vocab at 0x110dc8668>,
#  'speculations': <gensim.models.keyedvectors.Vocab at 0x110dc86a0>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x110dc86d8>,
#  'etiology': <gensim.models.keyedvectors.Vocab at 0x110dc8710>,
#  'insanities': <gensim.models.keyedvectors.Vocab at 0x110dc8748>,
#  'However': <gensim.models.keyedvectors.Vocab at 0x110dc8780>,
#  '1896': <gensim.models.keyedvectors.Vocab at 0x110dc87b8>,
#  '1926': <gensim.models.keyedvectors.Vocab at 0x110dc87f0>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x110dc8828>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x110dc8860>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x110dc8898>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x110dc88d0>,
#  'gradual': <gensim.models.keyedvectors.Vocab at 0x110dc8908>,
#  'systemic': <gensim.models.keyedvectors.Vocab at 0x110dc8940>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x110dc8978>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x110dc89b0>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x110dc89e8>,
#  'metabolic': <gensim.models.keyedvectors.Vocab at 0x110dc8a20>,
#  'affected': <gensim.models.keyedvectors.Vocab at 0x110dc8a58>,
#  'organs': <gensim.models.keyedvectors.Vocab at 0x110dc8a90>,
#  'nerves': <gensim.models.keyedvectors.Vocab at 0x110dc8ac8>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x110dc8b00>,
#  'cascade': <gensim.models.keyedvectors.Vocab at 0x110dc8b38>,
#  'Psychopathic': <gensim.models.keyedvectors.Vocab at 0x110dc8b70>,
#  'personalities': <gensim.models.keyedvectors.Vocab at 0x110dc8ba8>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x110dc8be0>,
#  'influential': <gensim.models.keyedvectors.Vocab at 0x110dc8c18>,
#  'section': <gensim.models.keyedvectors.Vocab at 0x110dc8c50>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x110dc8c88>,
#  'meant': <gensim.models.keyedvectors.Vocab at 0x110dc8cc0>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x110dc8cf8>,
#  'emotions': <gensim.models.keyedvectors.Vocab at 0x110dc8d30>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x110dc8d68>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x110dc8da0>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x110dc8dd8>,
#  'delusions': <gensim.models.keyedvectors.Vocab at 0x110dc8e10>,
#  'hallucinations': <gensim.models.keyedvectors.Vocab at 0x110dc8e48>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x110dc8e80>,
#  'sentiments': <gensim.models.keyedvectors.Vocab at 0x110dc8eb8>,
#  'counter': <gensim.models.keyedvectors.Vocab at 0x110dc8ef0>,
#  'ruthless': <gensim.models.keyedvectors.Vocab at 0x110dc8f28>,
#  'satisfaction': <gensim.models.keyedvectors.Vocab at 0x110dc8f60>,
#  'egotism': <gensim.models.keyedvectors.Vocab at 0x110dc8f98>,
#  'attributed': <gensim.models.keyedvectors.Vocab at 0x110dc8fd0>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x110dcc048>,
#  'degeneration': <gensim.models.keyedvectors.Vocab at 0x110dcc080>,
#  'redefinition': <gensim.models.keyedvectors.Vocab at 0x110dcc0b8>,
#  'Cesare': <gensim.models.keyedvectors.Vocab at 0x110dcc0f0>,
#  'Lombrosos': <gensim.models.keyedvectors.Vocab at 0x110dcc128>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x110dcc160>,
#  'conceptualised': <gensim.models.keyedvectors.Vocab at 0x110dcc198>,
#  'defect': <gensim.models.keyedvectors.Vocab at 0x110dcc1d0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x110dcc208>,
#  'stressed': <gensim.models.keyedvectors.Vocab at 0x110dcc240>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x110dcc278>,
#  'recognise': <gensim.models.keyedvectors.Vocab at 0x110dcc2b0>,
#  'characteristics': <gensim.models.keyedvectors.Vocab at 0x110dcc2e8>,
#  'Richard': <gensim.models.keyedvectors.Vocab at 0x110dcc320>,
#  'F.': <gensim.models.keyedvectors.Vocab at 0x110dcc358>,
#  'Wetzell': <gensim.models.keyedvectors.Vocab at 0x110dcc390>,
#  '2000': <gensim.models.keyedvectors.Vocab at 0x110dcc3c8>,
#  'pg': <gensim.models.keyedvectors.Vocab at 0x110dcc400>,
#  '59': <gensim.models.keyedvectors.Vocab at 0x110dcc438>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x110dcc470>,
#  '146': <gensim.models.keyedvectors.Vocab at 0x110dcc4a8>,
#  'misc': <gensim.models.keyedvectors.Vocab at 0x110dcc4e0>,
#  '1904': <gensim.models.keyedvectors.Vocab at 0x110dcc518>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x110dcc550>,
#  'heading': <gensim.models.keyedvectors.Vocab at 0x110dcc588>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x110dcc5c0>,
#  'Congenital': <gensim.models.keyedvectors.Vocab at 0x110dcc5f8>,
#  'feeblemindedness': <gensim.models.keyedvectors.Vocab at 0x110dcc630>,
#  'chapter': <gensim.models.keyedvectors.Vocab at 0x110dcc668>,
#  'They': <gensim.models.keyedvectors.Vocab at 0x110dcc6a0>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x110dcc6d8>,
#  'Four': <gensim.models.keyedvectors.Vocab at 0x110dcc710>,
#  'distinguished': <gensim.models.keyedvectors.Vocab at 0x110dcc748>,
#  'criminals': <gensim.models.keyedvectors.Vocab at 0x110dcc780>,
#  'inborn': <gensim.models.keyedvectors.Vocab at 0x110dcc7b8>,
#  'delinquents': <gensim.models.keyedvectors.Vocab at 0x110dcc7f0>,
#  'pathological': <gensim.models.keyedvectors.Vocab at 0x110dcc828>,
#  'liars': <gensim.models.keyedvectors.Vocab at 0x110dcc860>,
#  'querulous': <gensim.models.keyedvectors.Vocab at 0x110dcc898>,
#  'persons': <gensim.models.keyedvectors.Vocab at 0x110dcc8d0>,
#  'Triebmenschen': <gensim.models.keyedvectors.Vocab at 0x110dcc908>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x110dcc940>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x110dcc978>,
#  'compulsion': <gensim.models.keyedvectors.Vocab at 0x110dcc9b0>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x110dcc9e8>,
#  'Vagabond': <gensim.models.keyedvectors.Vocab at 0x110dcca20>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x110dcca58>,
#  'vagabonds': <gensim.models.keyedvectors.Vocab at 0x110dcca90>,
#  'spendthrifts': <gensim.models.keyedvectors.Vocab at 0x110dccac8>,
#  'dipsomaniacs': <gensim.models.keyedvectors.Vocab at 0x110dccb00>,
#  'psychopathic': <gensim.models.keyedvectors.Vocab at 0x110dccb38>,
#  'inferiorities': <gensim.models.keyedvectors.Vocab at 0x110dccb70>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x110dccba8>,
#  'popularised': <gensim.models.keyedvectors.Vocab at 0x110dccbe0>,
#  'Julius': <gensim.models.keyedvectors.Vocab at 0x110dccc18>,
#  'August': <gensim.models.keyedvectors.Vocab at 0x110dccc50>,
#  'Koch': <gensim.models.keyedvectors.Vocab at 0x110dccc88>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x110dcccc0>,
#  'congenital': <gensim.models.keyedvectors.Vocab at 0x110dcccf8>,
#  'acquired': <gensim.models.keyedvectors.Vocab at 0x110dccd30>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x110dccd68>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x110dccda0>,
#  'suggesting': <gensim.models.keyedvectors.Vocab at 0x110dccdd8>,
#  'assumption': <gensim.models.keyedvectors.Vocab at 0x110dcce10>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x110dcce48>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x110dcce80>,
#  'biologism': <gensim.models.keyedvectors.Vocab at 0x110dcceb8>,
#  'Others': <gensim.models.keyedvectors.Vocab at 0x110dccef0>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x110dccf28>,
#  'Gustav': <gensim.models.keyedvectors.Vocab at 0x110dccf60>,
#  'Aschaffenburg': <gensim.models.keyedvectors.Vocab at 0x110dccf98>,
#  'varying': <gensim.models.keyedvectors.Vocab at 0x110dccfd0>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x110ecf048>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x110ecf080>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x110ecf0b8>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x110ecf0f0>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x110ecf128>,
#  'questioned': <gensim.models.keyedvectors.Vocab at 0x110ecf160>,
#  'implies': <gensim.models.keyedvectors.Vocab at 0x110ecf198>,
#  'somehow': <gensim.models.keyedvectors.Vocab at 0x110ecf1d0>,
#  'unvarying': <gensim.models.keyedvectors.Vocab at 0x110ecf208>,
#  'vary': <gensim.models.keyedvectors.Vocab at 0x110ecf240>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x110ecf278>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x110ecf2b0>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x110ecf2e8>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x110ecf320>,
#  'Kurt': <gensim.models.keyedvectors.Vocab at 0x110ecf358>,
#  'Schneider': <gensim.models.keyedvectors.Vocab at 0x110ecf390>,
#  'criticized': <gensim.models.keyedvectors.Vocab at 0x110ecf3c8>,
#  'appearing': <gensim.models.keyedvectors.Vocab at 0x110ecf400>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x110ecf438>,
#  'behaviors': <gensim.models.keyedvectors.Vocab at 0x110ecf470>,
#  'undesirable': <gensim.models.keyedvectors.Vocab at 0x110ecf4a8>,
#  'Schneiders': <gensim.models.keyedvectors.Vocab at 0x110ecf4e0>,
#  'alternative': <gensim.models.keyedvectors.Vocab at 0x110ecf518>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x110ecf550>,
#  'criticised': <gensim.models.keyedvectors.Vocab at 0x110ecf588>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x110ecf5c0>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x110ecf5f8>,
#  'essentials': <gensim.models.keyedvectors.Vocab at 0x110ecf630>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x110ecf668>,
#  'remarkable': <gensim.models.keyedvectors.Vocab at 0x110ecf6a0>,
#  'similarities': <gensim.models.keyedvectors.Vocab at 0x110ecf6d8>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x110ecf710>,
#  'DSM-IV': <gensim.models.keyedvectors.Vocab at 0x110ecf748>,
#  'ICD-10': <gensim.models.keyedvectors.Vocab at 0x110ecf780>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x110ecf7b8>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x110ecf7f0>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x110ecf828>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x110ecf860>,
#  'psychopathy': <gensim.models.keyedvectors.Vocab at 0x110ecf898>,
#  'referred': <gensim.models.keyedvectors.Vocab at 0x110ecf8d0>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x110ecf908>,
#  'compulsive': <gensim.models.keyedvectors.Vocab at 0x110ecf940>,
#  'impulsive': <gensim.models.keyedvectors.Vocab at 0x110ecf978>,
#  'homosexuality': <gensim.models.keyedvectors.Vocab at 0x110ecf9b0>,
#  'disturbances': <gensim.models.keyedvectors.Vocab at 0x110ecf9e8>,
#  'From': <gensim.models.keyedvectors.Vocab at 0x110ecfa20>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x110ecfa58>,
#  'termed': <gensim.models.keyedvectors.Vocab at 0x110ecfa90>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x110ecfac8>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x110ecfb00>,
#  '1909': <gensim.models.keyedvectors.Vocab at 0x110ecfb38>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x110ecfb70>,
#  'dissocial': <gensim.models.keyedvectors.Vocab at 0x110ecfba8>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x110ecfbe0>,
#  'excitable': <gensim.models.keyedvectors.Vocab at 0x110ecfc18>,
#  'unstable': <gensim.models.keyedvectors.Vocab at 0x110ecfc50>,
#  'eccentrics': <gensim.models.keyedvectors.Vocab at 0x110ecfc88>,
#  'swindlers': <gensim.models.keyedvectors.Vocab at 0x110ecfcc0>,
#  'quarrelsome': <gensim.models.keyedvectors.Vocab at 0x110ecfcf8>,
#  'attenuated': <gensim.models.keyedvectors.Vocab at 0x110ecfd30>,
#  'mild': <gensim.models.keyedvectors.Vocab at 0x110ecfd68>,
#  'phases': <gensim.models.keyedvectors.Vocab at 0x110ecfda0>,
#  'depressive': <gensim.models.keyedvectors.Vocab at 0x110ecfdd8>,
#  'corresponds': <gensim.models.keyedvectors.Vocab at 0x110ecfe10>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x110ecfe48>,
#  'Alzheimers': <gensim.models.keyedvectors.Vocab at 0x110ecfe80>,
#  'postulated': <gensim.models.keyedvectors.Vocab at 0x110ecfeb8>,
#  'As': <gensim.models.keyedvectors.Vocab at 0x110ecfef0>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x110ecff28>,
#  'Alois': <gensim.models.keyedvectors.Vocab at 0x110ecff60>,
#  'Alzheimer': <gensim.models.keyedvectors.Vocab at 0x110ecff98>,
#  'co-discoverer': <gensim.models.keyedvectors.Vocab at 0x110ecffd0>,
#  'discovered': <gensim.models.keyedvectors.Vocab at 0x110ed2048>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x110ed2080>,
#  'pathologic': <gensim.models.keyedvectors.Vocab at 0x110ed20b8>,
#  'confident': <gensim.models.keyedvectors.Vocab at 0x110ed20f0>,
#  'someday': <gensim.models.keyedvectors.Vocab at 0x110ed2128>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x110ed2160>,
#  'Degeneration': <gensim.models.keyedvectors.Vocab at 0x110ed2198>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x110ed21d0>,
#  'Upon': <gensim.models.keyedvectors.Vocab at 0x110ed2208>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x110ed2240>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x110ed2278>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x110ed22b0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x110ed22e8>,
#  'proponent': <gensim.models.keyedvectors.Vocab at 0x110ed2320>,
#  'eugenics': <gensim.models.keyedvectors.Vocab at 0x110ed2358>,
#  'racial': <gensim.models.keyedvectors.Vocab at 0x110ed2390>,
#  'hygiene': <gensim.models.keyedvectors.Vocab at 0x110ed23c8>,
#  'publications': <gensim.models.keyedvectors.Vocab at 0x110ed2400>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x110ed2438>,
#  'alcoholism': <gensim.models.keyedvectors.Vocab at 0x110ed2470>,
#  'hysteria': <gensim.models.keyedvectors.Vocab at 0x110ed24a8>,
#  'concerned': <gensim.models.keyedvectors.Vocab at 0x110ed24e0>,
#  'preserve': <gensim.models.keyedvectors.Vocab at 0x110ed2518>,
#  'enhance': <gensim.models.keyedvectors.Vocab at 0x110ed2550>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x110ed2588>,
#  'Volk': <gensim.models.keyedvectors.Vocab at 0x110ed25c0>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x110ed25f8>,
#  'Lamarckian': <gensim.models.keyedvectors.Vocab at 0x110ed2630>,
#  'concepts': <gensim.models.keyedvectors.Vocab at 0x110ed2668>,
#  'evolution': <gensim.models.keyedvectors.Vocab at 0x110ed26a0>,
#  'cultural': <gensim.models.keyedvectors.Vocab at 0x110ed26d8>,
#  'deterioration': <gensim.models.keyedvectors.Vocab at 0x110ed2710>,
#  'inherited': <gensim.models.keyedvectors.Vocab at 0x110ed2748>,
#  'ally': <gensim.models.keyedvectors.Vocab at 0x110ed2780>,
#  'promoter': <gensim.models.keyedvectors.Vocab at 0x110ed27b8>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x110ed27f0>,
#  'Ernst': <gensim.models.keyedvectors.Vocab at 0x110ed2828>,
#  'Rudin': <gensim.models.keyedvectors.Vocab at 0x110ed2860>,
#  'clarify': <gensim.models.keyedvectors.Vocab at 0x110ed2898>,
#  'mechanisms': <gensim.models.keyedvectors.Vocab at 0x110ed28d0>,
#  'inheritance': <gensim.models.keyedvectors.Vocab at 0x110ed2908>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x110ed2940>,
#  'so-called': <gensim.models.keyedvectors.Vocab at 0x110ed2978>,
#  'empirical': <gensim.models.keyedvectors.Vocab at 0x110ed29b0>,
#  'Martin': <gensim.models.keyedvectors.Vocab at 0x110ed29e8>,
#  'Brune': <gensim.models.keyedvectors.Vocab at 0x110ed2a20>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x110ed2a58>,
#  'ardent': <gensim.models.keyedvectors.Vocab at 0x110ed2a90>,
#  'advocates': <gensim.models.keyedvectors.Vocab at 0x110ed2ac8>,
#  'self-domestication': <gensim.models.keyedvectors.Vocab at 0x110ed2b00>,
#  'darwinism': <gensim.models.keyedvectors.Vocab at 0x110ed2b38>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x110ed2b70>,
#  'allowing': <gensim.models.keyedvectors.Vocab at 0x110ed2ba8>,
#  'weeded': <gensim.models.keyedvectors.Vocab at 0x110ed2be0>,
#  'resulting': <gensim.models.keyedvectors.Vocab at 0x110ed2c18>,
#  'gene': <gensim.models.keyedvectors.Vocab at 0x110ed2c50>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x110ed2c88>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x110ed2cc0>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x110ed2cf8>,
#  'weakening': <gensim.models.keyedvectors.Vocab at 0x110ed2d30>,
#  'viability': <gensim.models.keyedvectors.Vocab at 0x110ed2d68>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x110ed2da0>,
#  'decreasing': <gensim.models.keyedvectors.Vocab at 0x110ed2dd8>,
#  'fertility': <gensim.models.keyedvectors.Vocab at 0x110ed2e10>,
#  'proletarianisation': <gensim.models.keyedvectors.Vocab at 0x110ed2e48>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x110ed2e80>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x110ed2eb8>,
#  'penning': <gensim.models.keyedvectors.Vocab at 0x110ed2ef0>,
#  'idiots': <gensim.models.keyedvectors.Vocab at 0x110ed2f28>,
#  'epileptics': <gensim.models.keyedvectors.Vocab at 0x110ed2f60>,
#  'psychopaths': <gensim.models.keyedvectors.Vocab at 0x110ed2f98>,
#  'prostitutes': <gensim.models.keyedvectors.Vocab at 0x110ed2fd0>,
#  'tramps': <gensim.models.keyedvectors.Vocab at 0x110ed6048>,
#  'descend': <gensim.models.keyedvectors.Vocab at 0x110ed6080>,
#  'alcoholic': <gensim.models.keyedvectors.Vocab at 0x110ed60b8>,
#  'syphilitic': <gensim.models.keyedvectors.Vocab at 0x110ed60f0>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x110ed6128>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x110ed6160>,
#  'inferiority': <gensim.models.keyedvectors.Vocab at 0x110ed6198>,
#  'offspring': <gensim.models.keyedvectors.Vocab at 0x110ed61d0>,
#  'incalculable': <gensim.models.keyedvectors.Vocab at 0x110ed6208>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x110ed6240>,
#  'well-known': <gensim.models.keyedvectors.Vocab at 0x110ed6278>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x110ed62b0>,
#  'Jews': <gensim.models.keyedvectors.Vocab at 0x110ed62e8>,
#  'disposition': <gensim.models.keyedvectors.Vocab at 0x110ed6320>,
#  'nervous': <gensim.models.keyedvectors.Vocab at 0x110ed6358>,
#  'teaches': <gensim.models.keyedvectors.Vocab at 0x110ed6390>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x110ed63c8>,
#  'extraordinarily': <gensim.models.keyedvectors.Vocab at 0x110ed6400>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x110ed6438>,
#  'domestication': <gensim.models.keyedvectors.Vocab at 0x110ed6470>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x110ed64a8>,
#  'imprint': <gensim.models.keyedvectors.Vocab at 0x110ed64e0>,
#  'marks': <gensim.models.keyedvectors.Vocab at 0x110ed6518>,
#  'nosological': <gensim.models.keyedvectors.Vocab at 0x110ed6550>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x110ed6588>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x110ed65c0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x110ed65f8>,
#  'paradigm': <gensim.models.keyedvectors.Vocab at 0x110ed6630>,
#  'Robert': <gensim.models.keyedvectors.Vocab at 0x110ed6668>,
#  'Spitzer': <gensim.models.keyedvectors.Vocab at 0x110ed66a0>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x110ed66d8>,
#  'DSM': <gensim.models.keyedvectors.Vocab at 0x110ed6710>,
#  'committees': <gensim.models.keyedvectors.Vocab at 0x110ed6748>,
#  'keen': <gensim.models.keyedvectors.Vocab at 0x110ed6780>,
#  'assumptions': <gensim.models.keyedvectors.Vocab at 0x110ed67b8>,
#  'causation': <gensim.models.keyedvectors.Vocab at 0x110ed67f0>,
#  'Special': <gensim.models.keyedvectors.Vocab at 0x110ed6828>,
#  'Edition': <gensim.models.keyedvectors.Vocab at 0x110ed6860>,
#  'History': <gensim.models.keyedvectors.Vocab at 0x110ed6898>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x110ed68d0>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x110ed6908>,
#  '337': <gensim.models.keyedvectors.Vocab at 0x110ed6940>,
#  '360': <gensim.models.keyedvectors.Vocab at 0x110ed6978>,
#  'DOI': <gensim.models.keyedvectors.Vocab at 0x110ed69b0>,
#  '10.1177': <gensim.models.keyedvectors.Vocab at 0x110ed69e8>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x110ed6a20>,
#  '0957154X07078976': <gensim.models.keyedvectors.Vocab at 0x110ed6a58>,
#  'scientific': <gensim.models.keyedvectors.Vocab at 0x110ed6a90>,
#  'manager': <gensim.models.keyedvectors.Vocab at 0x110ed6ac8>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x110ed6b00>,
#  'operator': <gensim.models.keyedvectors.Vocab at 0x110ed6b38>,
#  'large-scale': <gensim.models.keyedvectors.Vocab at 0x110ed6b70>,
#  'clinically': <gensim.models.keyedvectors.Vocab at 0x110ed6ba8>,
#  'oriented': <gensim.models.keyedvectors.Vocab at 0x110ed6be0>,
#  'epidemiological': <gensim.models.keyedvectors.Vocab at 0x110ed6c18>,
#  'programme': <gensim.models.keyedvectors.Vocab at 0x110ed6c50>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x110ed6c88>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x110ed6cc0>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x110ed6cf8>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x110ed6d30>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x110ed6d68>,
#  'sources': <gensim.models.keyedvectors.Vocab at 0x110ed6da0>,
#  'networks': <gensim.models.keyedvectors.Vocab at 0x110ed6dd8>,
#  'Despite': <gensim.models.keyedvectors.Vocab at 0x110ed6e10>,
#  'proclaiming': <gensim.models.keyedvectors.Vocab at 0x110ed6e48>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x110ed6e80>,
#  'standards': <gensim.models.keyedvectors.Vocab at 0x110ed6eb8>,
#  'himself': <gensim.models.keyedvectors.Vocab at 0x110ed6ef0>,
#  'gather': <gensim.models.keyedvectors.Vocab at 0x110ed6f28>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x110ed6f60>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x110ed6f98>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x110ed6fd0>,
#  'draw': <gensim.models.keyedvectors.Vocab at 0x110eda048>,
#  'observations': <gensim.models.keyedvectors.Vocab at 0x110eda080>,
#  'officials': <gensim.models.keyedvectors.Vocab at 0x110eda0b8>,
#  'trained': <gensim.models.keyedvectors.Vocab at 0x110eda0f0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x110eda128>,
#  'editions': <gensim.models.keyedvectors.Vocab at 0x110eda160>,
#  'textbooks': <gensim.models.keyedvectors.Vocab at 0x110eda198>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x110eda1d0>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x110eda208>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x110eda240>,
#  'individuals': <gensim.models.keyedvectors.Vocab at 0x110eda278>,
#  'mosaic-like': <gensim.models.keyedvectors.Vocab at 0x110eda2b0>,
#  'compilations': <gensim.models.keyedvectors.Vocab at 0x110eda2e8>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x110eda320>,
#  'statements': <gensim.models.keyedvectors.Vocab at 0x110eda358>,
#  'diagnosis': <gensim.models.keyedvectors.Vocab at 0x110eda390>,
#  'broader': <gensim.models.keyedvectors.Vocab at 0x110eda3c8>,
#  'bourgeois': <gensim.models.keyedvectors.Vocab at 0x110eda400>,
#  'reactionary': <gensim.models.keyedvectors.Vocab at 0x110eda438>,
#  'citizen': <gensim.models.keyedvectors.Vocab at 0x110eda470>,
#  'knapp': <gensim.models.keyedvectors.Vocab at 0x110eda4a8>,
#  'und': <gensim.models.keyedvectors.Vocab at 0x110eda4e0>,
#  'klar': <gensim.models.keyedvectors.Vocab at 0x110eda518>,
#  'concise': <gensim.models.keyedvectors.Vocab at 0x110eda550>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x110eda588>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x110eda5c0>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x110eda5f8>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x110eda630>,
#  'physicians': <gensim.models.keyedvectors.Vocab at 0x110eda668>,
#  'Abridged': <gensim.models.keyedvectors.Vocab at 0x110eda6a0>,
#  'clumsy': <gensim.models.keyedvectors.Vocab at 0x110eda6d8>,
#  'English': <gensim.models.keyedvectors.Vocab at 0x110eda710>,
#  'translations': <gensim.models.keyedvectors.Vocab at 0x110eda748>,
#  'seventh': <gensim.models.keyedvectors.Vocab at 0x110eda780>,
#  '1902': <gensim.models.keyedvectors.Vocab at 0x110eda7b8>,
#  '1907': <gensim.models.keyedvectors.Vocab at 0x110eda7f0>,
#  'respectively': <gensim.models.keyedvectors.Vocab at 0x110eda828>,
#  'Allan': <gensim.models.keyedvectors.Vocab at 0x110eda860>,
#  'Ross': <gensim.models.keyedvectors.Vocab at 0x110eda898>,
#  'Diefendorf': <gensim.models.keyedvectors.Vocab at 0x110eda8d0>,
#  '1871-1943': <gensim.models.keyedvectors.Vocab at 0x110eda908>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x110eda940>,
#  'assistant': <gensim.models.keyedvectors.Vocab at 0x110eda978>,
#  'physician': <gensim.models.keyedvectors.Vocab at 0x110eda9b0>,
#  'Connecticut': <gensim.models.keyedvectors.Vocab at 0x110eda9e8>,
#  ...}

# %%
model_en.wv.most_similar(['German'])
# Out:
# [('Ultramarinas', 0.46172091364860535),
#  ('Pepe', 0.44785213470458984),
#  ('vice-principal', 0.4434520900249481),
#  ('transmit/receive', 0.4318106472492218),
#  ('Anushtubh', 0.42985594272613525),
#  ('Baccalaureate', 0.42230531573295593),
#  ('范陽王', 0.41674861311912537),
#  ('pumped-out', 0.41333553194999695),
#  ('http://www.cntraveler.com/readers-choice/2011/europe/top-10-islands-europe#slide=1',
#   0.4023128151893616),
#  ('Announcers', 0.4007004499435425)]

# %%
model_en.init_sims(replace=True)

# %%
model_en.save('w2v_en.model')
